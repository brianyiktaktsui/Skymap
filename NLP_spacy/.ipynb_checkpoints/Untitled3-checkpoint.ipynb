# %%
# %matplotlib inline
import matplotlib.pyplot as plt
#plt.axis('off')

#!cp /cellar/users/btsui/Downloads/Thesaurus.txt .

# %% [markdown]
# ###
#
# objective: map the srs freetext to NCIT
#
# copied from
# https://evs.nci.nih.gov/ftp1/NCI_Thesaurus/ReadMe.txt:
#
#
# "
# If a "parents", "synonyms", "display name", or "concept status" field contains multiple entries, these are pipe-delimited.
# For root concepts without "parents", this field contains the string "root_node".  The
# first entry in the "synonyms" field is the preferred name of the concept.  If no preferred
# name has been stated for the concept, this field contains the concept name.  The "definition"
# field contains only one definition if more than one definition is associated with the concept;
# not all concepts contain definitions.  A "display_name" or "concept status" may contain zero values.
# The "semantic type" field is guaranteed to contain one or more values.
# "
#
#
# First in synonym is the official name used on the NCIT website.
#
# Thesaurus.txt is pulled from  https://evs.nci.nih.gov/ftp1/NCI_Thesaurus/ReadMe.txt

# %%
import pandas as pd
import seaborn as sns
sns.set_style('white')

# %%
ncitT=pd.read_csv('Thesaurus.txt',sep='\t',header=None)

# %%
#'code <tab> concept name <tab> parents <tab> synonyms <tab> definition <tab> display name <tab> concept status <tab> semantic type <EOL>'.split('<tab>')

# %%
col=['code',
 'concept name',
 'parents',
 'synonyms',
 'definition',
 'display name',
 'concept status',
 'semantic type']
ncitT.columns=col

# %% [markdown]
# ###
#
# is any of the code re

# %%
ncitT['concept name'].values[:10]
# Out:
# array(['<http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C100000>',
#        '<http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C100001>',
#        '<http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C100002>',
#        '<http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C100003>',
#        '<http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C100004>',
#        '<http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C100005>',
#        '<http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C100006>',
#        '<http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C100007>',
#        '<http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C100008>',
#        '<http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C100009>'],
#       dtype=object)

# %%
ignoreConceptStatus=['Retired_Concept', 'Obsolete_Concept', 'Header_Concept',
       'Provisional_Concept', 'Header_Concept|Retired_Concept',
       'Header_Concept|Obsolete_Concept']
m_concept=~ncitT['concept status'].isin(ignoreConceptStatus)
m=m_concept
ncitSubDf=ncitT[m]

# %%
#ncitT[ncitT['display name']=='Heart']

# %%
myIndexOrder=['code','concept name','parents','definition','semantic type']
tmpS=ncitSubDf.set_index(myIndexOrder)['synonyms']

# %%
tmpS2=tmpS.str.split('|',expand=True).stack()

# %%
tmpDf=tmpS2.to_frame()

# %%
tmpDf.index.names=myIndexOrder+['n_th synonym']

# %%
tmpDf.columns=['synonyms']

# %%
##!mkdir Data

# %%
tmpDf.to_pickle('./Data/')
# Out:
#                                                                                                                                                                                                                          synonyms
# code    concept name                                       parents    definition                                         semantic type                            n_th synonym
# C100000 <http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus... C49803     A percutaneous coronary intervention is necessa... Therapeutic or Preventive Procedure      0             Percutaneous Coronary Intervention for ST Elev...
#                                                                                                                                                                   1             PERCUTANEOUS CORONARY INTERVENTION (PCI) FOR S...
# C100001 <http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus... C49803     A percutaneous coronary intervention is necessa... Therapeutic or Preventive Procedure      0             Percutaneous Coronary Intervention for ST Elev...
#                                                                                                                                                                   1             PERCUTANEOUS CORONARY INTERVENTION (PCI) FOR S...
# C100002 <http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus... C49803     A percutaneous coronary intervention is necessa... Therapeutic or Preventive Procedure      0             Percutaneous Coronary Intervention for ST Elev...
#                                                                                                                                                                   1             PERCUTANEOUS CORONARY INTERVENTION (PCI) FOR S...
# C100003 <http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus... C80449     Invasive procedure through a puncture in the sk... Therapeutic or Preventive Procedure      0                              Percutaneous Mitral Valve Repair
#                                                                                                                                                                   1                                    PERCUTANEOUS MITRAL REPAIR
# C100004 <http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus... C80430     Removal or resection of the pericardium. (ACC)     Therapeutic or Preventive Procedure      0                                         Pericardial Stripping
#                                                                                                                                                                   1                                         PERICARDIAL STRIPPING
# C100005 <http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus... C15839     A procedure to evaluate the health of the an in... Health Care Activity                     0                            Post-Cardiac Transplant Evaluation
#                                                                                                                                                                   1                                       POST-CARDIAC TRANSPLANT
# C100006 <http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus... C139982    A procedure to evaluate the health of the cardi... Health Care Activity                     0             Pre-Operative Evaluation for Non-Cardiovascula...
#                                                                                                                                                                   1             PRE-OPERATIVE EVALUATION FOR NON-CARDIOVASCULA...
# C100007 <http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus... C99896     The coronary sinus / left ventricular lead was ... Finding                                  0                             Previously Implanted Cardiac Lead
#                                                                                                                                                                   1                                          PREVIOUSLY IMPLANTED
# C100008 <http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus... C49803     A percutaneous coronary intervention is imperat... Therapeutic or Preventive Procedure      0             Rescue Percutaneous Coronary Intervention for ...
#                                                                                                                                                                   1             RESCUE PERCUTANEOUS CORONARY INTERVENTION (PCI...
# C100009 <http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus... C99896     The cardiac lead has been left in situ and reus... Finding                                  0                                           Reused Cardiac Lead
# C100010 <http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus... C80430     A procedure involving a mechanical pump which r... Therapeutic or Preventive Procedure      0               Right Cardiac Ventricle Assist Device Procedure
#                                                                                                                                                                   1                               RIGHT VENTRICULAR ASSIST DEVICE
#                                                                                                                                                                   2                                                          RVAD
# C100011 <http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus... C63169     The cardiac rhythm device malfunction affected ... Event                                    0                    Right Cardiac Ventricle Pacing Malfunction
#                                                                                                                                                                   1                          RIGHT VENTRICULAR PACING MALFUNCTION
# C100012 <http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus... C50797     Evidence of severe retrograde blood flow throug... Disease or Syndrome                      0                            Severe Cardiac Valve Regurgitation
# C100013 <http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus... C62433     The cardiac valve orifice is abnormally narrow,... Finding                                  0                                 Severe Cardiac Valve Stenosis
# C100014 <http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus... C111103    An electrocardiographic finding of ventricular ... Finding                                  0             Spontaneous Sustained Ventricular Tachycardia ...
#                                                                                                                                                                   1                 SPONTANEOUS SUSTAINED VENTRICULAR TACHYCARDIA
#                                                                                                                                                                   2                 Spontaneous Sustained Ventricular Tachycardia
#                                                                                                                                                                   3             Spontaneous Sustained Ventricular Tachycardia ...
# ...                                                                                                                                                                                                                           ...
# C99998  <http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus... C80430     A procedure involving an electronic device that... Therapeutic or Preventive Procedure      0                                           Pacemaker Procedure
#                                                                                                                                                                   1                                                     PACEMAKER
# C99999  <http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus... C49803     Includes patients with unstable angina or Non-S... Therapeutic or Preventive Procedure      0             Percutaneous Coronary Intervention for High Ri...
#                                                                                                                                                                   1             PERCUTANEOUS CORONARY INTERVENTION (PCI) FOR H...
# C999    <http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus... C582|C1968 The dihydrochloride salt of amonafide, an imide... Organic Chemical|Pharmacologic Substance 0                                     Amonafide Dihydrochloride
#                                                                                                                                                                   1             1H-benz(de)isoquinoline-1,3(2H)-dione, 5-amino...
#                                                                                                                                                                   2                                     AMONAFIDE DIHYDROCHLORIDE
#                                                                                                                                                                   3                                                     Amonafide
#                                                                                                                                                                   4                                       Amonafide Hydrochloride
#                                                                                                                                                                   5                                                          BIDA
#                                                                                                                                                                   6                                         Benzisoquinolinedione
#                                                                                                                                                                   7                                                      M-FA-142
#                                                                                                                                                                   8                                                    Nafidimide
#                                                                                                                                                                   9                                                      Quinamed
#                                                                                                                                                                   10                                                    amonafide
# C104171 <http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus... C28428     NaN                                                Conceptual Entity                        0                                          Retired Concept 2012
# C113462 <http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus... C28428     NaN                                                Conceptual Entity                        0                                          Retired Concept 2013
# C120167 <http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus... C28428     NaN                                                Conceptual Entity                        0                                          Retired Concept 2014
# C125190 <http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus... C28428     NaN                                                Conceptual Entity                        0                                          Retired Concept 2015
# C131742 <http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus... C28428     NaN                                                Conceptual Entity                        0                                          Retired Concept 2016
# C83479  <http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus... C28428     NaN                                                Conceptual Entity                        0                                          Retired Concept 2003
# C83480  <http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus... C28428     NaN                                                Conceptual Entity                        0                                          Retired Concept 2004
# C83481  <http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus... C28428     NaN                                                Conceptual Entity                        0                                          Retired Concept 2005
# C83482  <http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus... C28428     NaN                                                Conceptual Entity                        0                                          Retired Concept 2006
# C83483  <http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus... C28428     NaN                                                Conceptual Entity                        0                                          Retired Concept 2007
# C83484  <http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus... C28428     NaN                                                Conceptual Entity                        0                                          Retired Concept 2008
# C83485  <http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus... C28428     NaN                                                Conceptual Entity                        0                                  Retired Concept Current Year
# C85834  <http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus... C28428     NaN                                                Conceptual Entity                        0                                          Retired Concept 2009
# C95421  <http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus... C28428     NaN                                                Conceptual Entity                        0                                          Retired Concept 2010
# C99526  <http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus... C28428     NaN                                                Conceptual Entity                        0                                          Retired Concept 2011
#
# [433469 rows x 1 columns]

# %%
ax=tmpDf['synonyms'].str.len()[tmpDf['synonyms'].str.len()<200].hist()
print ("median len of synonyms:",tmpDf['synonyms'].str.len().median())
ax.set_ylabel('# of NCIT synonyms')
ax.grid(False)

ax.set_xlabel('synonym length')
# Out:
# median len of synonyms: 20.0
# Text(0.5,0,'synonym length')

# %%
ncitT.head(n=10)
# Out:
#       code                                       concept name  parents  \
# 0  C100000  <http://ncicb.nci.nih.gov/xml/owl/EVS/Thesauru...   C49803
# 1  C100001  <http://ncicb.nci.nih.gov/xml/owl/EVS/Thesauru...   C49803
# 2  C100002  <http://ncicb.nci.nih.gov/xml/owl/EVS/Thesauru...   C49803
# 3  C100003  <http://ncicb.nci.nih.gov/xml/owl/EVS/Thesauru...   C80449
# 4  C100004  <http://ncicb.nci.nih.gov/xml/owl/EVS/Thesauru...   C80430
# 5  C100005  <http://ncicb.nci.nih.gov/xml/owl/EVS/Thesauru...   C15839
# 6  C100006  <http://ncicb.nci.nih.gov/xml/owl/EVS/Thesauru...  C139982
# 7  C100007  <http://ncicb.nci.nih.gov/xml/owl/EVS/Thesauru...   C99896
# 8  C100008  <http://ncicb.nci.nih.gov/xml/owl/EVS/Thesauru...   C49803
# 9  C100009  <http://ncicb.nci.nih.gov/xml/owl/EVS/Thesauru...   C99896
#
#                                             synonyms  \
# 0  Percutaneous Coronary Intervention for ST Elev...
# 1  Percutaneous Coronary Intervention for ST Elev...
# 2  Percutaneous Coronary Intervention for ST Elev...
# 3  Percutaneous Mitral Valve Repair|PERCUTANEOUS ...
# 4        Pericardial Stripping|PERICARDIAL STRIPPING
# 5  Post-Cardiac Transplant Evaluation|POST-CARDIA...
# 6  Pre-Operative Evaluation for Non-Cardiovascula...
# 7  Previously Implanted Cardiac Lead|PREVIOUSLY I...
# 8  Rescue Percutaneous Coronary Intervention for ...
# 9                                Reused Cardiac Lead
#
#                                           definition display name  \
# 0  A percutaneous coronary intervention is necess...          NaN
# 1  A percutaneous coronary intervention is necess...          NaN
# 2  A percutaneous coronary intervention is necess...          NaN
# 3  Invasive procedure through a puncture in the s...          NaN
# 4     Removal or resection of the pericardium. (ACC)          NaN
# 5  A procedure to evaluate the health of the an i...          NaN
# 6  A procedure to evaluate the health of the card...          NaN
# 7  The coronary sinus / left ventricular lead was...          NaN
# 8  A percutaneous coronary intervention is impera...          NaN
# 9  The cardiac lead has been left in situ and reu...          NaN
#
#   concept status                        semantic type
# 0            NaN  Therapeutic or Preventive Procedure
# 1            NaN  Therapeutic or Preventive Procedure
# 2            NaN  Therapeutic or Preventive Procedure
# 3            NaN  Therapeutic or Preventive Procedure
# 4            NaN  Therapeutic or Preventive Procedure
# 5            NaN                 Health Care Activity
# 6            NaN                 Health Care Activity
# 7            NaN                              Finding
# 8            NaN  Therapeutic or Preventive Procedure
# 9            NaN                              Finding

# %%
ncitT.head(n=10).to_csv('tmp.tsv',sep='\t')
