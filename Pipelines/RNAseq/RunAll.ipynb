# %% [markdown]
# | Pipeline Code|
# |---- |
# | [Calcualate unprocessed](./calculate_unprocessed.ipynb)|
# | [merge RNAseq data into transcripts](./merge/mergeKallistoOutputIntoTranscript.ipynb)|
# | [reduce transcripts count to gene count using sum ](./Pipelines/RNAseq/merge/reduceToGeneLevel.ipynb)|
# |[merge data into single numpy mmap matrix ](./Pipelines/RNAseq/merge/mergeGeneMatrix.ipynb)
# | [upload expression data to AWS (On this step now)](./Pipelines/RNAseq/merge/upload_AWS.ipynb)|
#
# |Auxilary Code|
# |---- |
# | [file count](./Pipelines/RNAseq/merge/fileCount.ipynb)|
# | [merge Kalististo mapping stats](./Pipelines/RNAseq/merge/mergeKalistoMappingStats.ipynb)|
#
#
# Status
#
# * [Generating refs](http://localhost:6001/notebooks/Project/METAMAP/notebook/RapMapTest/RNAseq/generateReferences.ipynb)
# * Running all the new RNAseq data now

# %% [markdown]
# ### submit jobs to cluster

# %%
# %%bash
# time jupyter nbconvert --execute --to notebook --ExecutePreprocessor.timeout=-1 --inplace calculate_unprocessed.ipynb
# Out:
# Your job-array 444392.1-488705:1 ("all_seq.sh") has been submitted
# [NbConvertApp] Converting notebook calculate_unprocessed.ipynb to notebook
# [NbConvertApp] Executing notebook with kernel: python3
# Permission denied, please try again.
# Permission denied, please try again.
# Permission denied (publickey,password).
# Permission denied, please try again.
# Permission denied, please try again.
# Permission denied (publickey,password).
# Permission denied, please try again.
# Permission denied, please try again.
# Permission denied (publickey,password).
# Permission denied, please try again.
# Permission denied, please try again.
# Permission denied (publickey,password).
# [NbConvertApp] ERROR | Error while converting 'calculate_unprocessed.ipynb'
# Traceback (most recent call last):
#   File "/cellar/users/btsui/anaconda3/lib/python3.6/site-packages/nbconvert/nbconvertapp.py", line 393, in export_single_notebook
#     output, resources = self.exporter.from_filename(notebook_filename, resources=resources)
#   File "/cellar/users/btsui/anaconda3/lib/python3.6/site-packages/nbconvert/exporters/exporter.py", line 174, in from_filename
#     return self.from_file(f, resources=resources, **kw)
#   File "/cellar/users/btsui/anaconda3/lib/python3.6/site-packages/nbconvert/exporters/exporter.py", line 192, in from_file
#     return self.from_notebook_node(nbformat.read(file_stream, as_version=4), resources=resources, **kw)
#   File "/cellar/users/btsui/anaconda3/lib/python3.6/site-packages/nbconvert/exporters/notebook.py", line 31, in from_notebook_node
#     nb_copy, resources = super(NotebookExporter, self).from_notebook_node(nb, resources, **kw)
#   File "/cellar/users/btsui/anaconda3/lib/python3.6/site-packages/nbconvert/exporters/exporter.py", line 134, in from_notebook_node
#     nb_copy, resources = self._preprocess(nb_copy, resources)
#   File "/cellar/users/btsui/anaconda3/lib/python3.6/site-packages/nbconvert/exporters/exporter.py", line 311, in _preprocess
#     nbc, resc = preprocessor(nbc, resc)
#   File "/cellar/users/btsui/anaconda3/lib/python3.6/site-packages/nbconvert/preprocessors/base.py", line 47, in __call__
#     return self.preprocess(nb, resources)
#   File "/cellar/users/btsui/anaconda3/lib/python3.6/site-packages/nbconvert/preprocessors/execute.py", line 262, in preprocess
#     nb, resources = super(ExecutePreprocessor, self).preprocess(nb, resources)
#   File "/cellar/users/btsui/anaconda3/lib/python3.6/site-packages/nbconvert/preprocessors/base.py", line 69, in preprocess
#     nb.cells[index], resources = self.preprocess_cell(cell, resources, index)
#   File "/cellar/users/btsui/anaconda3/lib/python3.6/site-packages/nbconvert/preprocessors/execute.py", line 286, in preprocess_cell
#     raise CellExecutionError.from_cell_and_msg(cell, out)
# nbconvert.preprocessors.execute.CellExecutionError: An error occurred while executing the following cell:
# ------------------
# hitDf=targetMetaDF.loc[['SRR998545','SRR998530','SRR949118']]
# ------------------
#
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-36-80bc64521e31> in <module>()
# ----> 1 hitDf=targetMetaDF.loc[['SRR998545','SRR998530','SRR949118']]
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1476
#    1477             maybe_callable = com._apply_if_callable(key, self.obj)
# -> 1478             return self._getitem_axis(maybe_callable, axis=axis)
#    1479
#    1480     def _is_scalar_access(self, key):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1899                     raise ValueError('Cannot index with multidimensional key')
#    1900
# -> 1901                 return self._getitem_iterable(key, axis=axis)
#    1902
#    1903             # nested tuple slicing
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_iterable(self, key, axis)
#    1141             if labels.is_unique and Index(keyarr).is_unique:
#    1142                 indexer = ax.get_indexer_for(key)
# -> 1143                 self._validate_read_indexer(key, indexer, axis)
#    1144
#    1145                 d = {axis: [ax.reindex(keyarr)[0], indexer]}
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis)
#    1204                 raise KeyError(
#    1205                     u"None of [{key}] are in the [{axis}]".format(
# -> 1206                         key=key, axis=self.obj._get_axis_name(axis)))
#    1207
#    1208             # we skip the warning on Categorical/Interval
#
# KeyError: "None of [['SRR998545', 'SRR998530', 'SRR949118']] are in the [index]"
# KeyError: "None of [['SRR998545', 'SRR998530', 'SRR949118']] are in the [index]"
#
#
# real	2m38.767s
# user	2m1.596s
# sys	0m59.428s

# %%
#!cat single_rna.py

# %% [markdown]
# [click her for notebook](./merge/mergeKallistoOutputIntoTranscript.ipynb)

# %%
# %%bash
# cd merge
# time jupyter nbconvert --execute --to notebook --ExecutePreprocessor.timeout=-1 --inplace mergeKallistoOutputIntoTranscript.ipynb

# %%
# %%bash
# cd merge
# time jupyter nbconvert --execute --to notebook --ExecutePreprocessor.timeout=-1 --inplace reduceToGeneLevel.ipynb

# %%
# %%bash
# cd merge
# time jupyter nbconvert --execute --to notebook --ExecutePreprocessor.timeout=-1 --inplace mergeGeneMatrix.ipynb

# %%
#!cat ./merge/mergeGeneMatrix.ipynb

# %%
# %%bash
# cd mergeGeneMatrix.ipynb
# time jupyter nbconvert --execute --to notebook --ExecutePreprocessor.timeout=-1 --inplace upload_AWS.ipynb

# %%
# %%bash
# cd merge/mergeKalistoMappingStats.ipynb
# time jupyter nbconvert --execute --to notebook --ExecutePreprocessor.timeout=-1 --inplace upload_AWS.ipynb

# %%
#!mv /nrnb/users/btsui/Data/all_seq/rnaseq_merged_chunks/ /nrnb/users/btsui/Data/all_seq/rnaseq_merged_chunks_old_v2/

# %%
#!mkdir /nrnb/users/btsui/Data/all_seq/rnaseq_merged_chunks/

# %%
# !ls -laht /nrnb/users/btsui/Data/all_seq/rnaseq_merged_chunks/ | head
# Out:
# total 299G
# -rw-r--r--  1 btsui users    0 Oct 26 10:46 Homo_sapiens.transcript.est_counts.SRR10.pickle
# drwxr-xr-x  2 btsui users 128K Oct 26 10:46 .
# -rw-r--r--  1 btsui users  15G Oct 26 10:36 Homo_sapiens.transcript.est_counts.ERR20.pickle
# -rw-r--r--  1 btsui users 6.8G Oct 26 10:27 Homo_sapiens.transcript.est_counts.SRR15.pickle
# -rw-r--r--  1 btsui users  15G Oct 26 10:27 Homo_sapiens.transcript.est_counts.SRR12.pickle
# -rw-r--r--  1 btsui users 9.6G Oct 26 10:17 Homo_sapiens.transcript.est_counts.SRR8.pickle
# -rw-r--r--  1 btsui users 8.2G Oct 26 10:11 Homo_sapiens.transcript.est_counts.ERR17.pickle
# -rw-r--r--  1 btsui users 2.0G Oct 26 10:04 Homo_sapiens.transcript.est_counts.SRR9.pickle
# -rw-r--r--  1 btsui users 7.3G Oct 26 00:05 Homo_sapiens.transcript.est_counts.SRR76.pickle
# ls: write error: Broken pipe

# %%
# !ls -laht /nrnb/users/btsui/Data/all_seq/rnaseq_merged_chunks/
# Out:
# total 1.5T
# -rw-r--r--  1 btsui users 131M Oct 28 09:28 Mus_musculus.transcript.tpm.SRR78.pickle
# drwxr-xr-x  2 btsui users 128K Oct 28 09:28 .
# -rw-r--r--  1 btsui users 1.4G Oct 28 09:27 Mus_musculus.transcript.tpm.SRR77.pickle
# -rw-r--r--  1 btsui users 503M Oct 28 09:12 Mus_musculus.transcript.tpm.SRR74.pickle
# -rw-r--r--  1 btsui users 286M Oct 28 09:07 Mus_musculus.transcript.tpm.SRR73.pickle
# -rw-r--r--  1 btsui users 4.0G Oct 28 09:03 Mus_musculus.transcript.tpm.SRR72.pickle
# -rw-r--r--  1 btsui users  14M Oct 28 08:22 Mus_musculus.transcript.tpm.SRR46.pickle
# -rw-r--r--  1 btsui users  19M Oct 28 08:21 Mus_musculus.transcript.tpm.SRR45.pickle
# -rw-r--r--  1 btsui users 3.4G Oct 28 08:21 Mus_musculus.transcript.tpm.SRR71.pickle
# -rw-r--r--  1 btsui users 844M Oct 28 08:20 Mus_musculus.transcript.tpm.SRR75.pickle
# -rw-r--r--  1 btsui users 922M Oct 28 08:11 Mus_musculus.transcript.tpm.SRR76.pickle
# -rw-r--r--  1 btsui users 6.3G Oct 28 08:00 Mus_musculus.transcript.tpm.SRR67.pickle
# -rw-r--r--  1 btsui users  51M Oct 28 07:44 Mus_musculus.transcript.tpm.SRR49.pickle
# -rw-r--r--  1 btsui users  11G Oct 28 07:41 Mus_musculus.transcript.tpm.SRR66.pickle
# -rw-r--r--  1 btsui users 140M Oct 28 07:15 Mus_musculus.transcript.tpm.SRR38.pickle
# -rw-r--r--  1 btsui users 389M Oct 28 07:14 Mus_musculus.transcript.tpm.SRR41.pickle
# -rw-r--r--  1 btsui users 838M Oct 28 07:09 Mus_musculus.transcript.tpm.SRR43.pickle
# -rw-r--r--  1 btsui users 5.2G Oct 28 06:58 Mus_musculus.transcript.tpm.SRR52.pickle
# -rw-r--r--  1 btsui users 2.4G Oct 28 06:49 Mus_musculus.transcript.tpm.SRR69.pickle
# -rw-r--r--  1 btsui users 1.6G Oct 28 06:21 Mus_musculus.transcript.tpm.SRR70.pickle
# -rw-r--r--  1 btsui users 350M Oct 28 06:04 Mus_musculus.transcript.tpm.SRR27.pickle
# -rw-r--r--  1 btsui users 675M Oct 28 06:00 Mus_musculus.transcript.tpm.SRR37.pickle
# -rw-r--r--  1 btsui users 370M Oct 28 05:55 Mus_musculus.transcript.tpm.SRR47.pickle
# -rw-r--r--  1 btsui users 3.0G Oct 28 05:51 Mus_musculus.transcript.tpm.SRR40.pickle
# -rw-r--r--  1 btsui users 9.2G Oct 28 05:49 Mus_musculus.transcript.tpm.SRR60.pickle
# -rw-r--r--  1 btsui users 3.8G Oct 28 05:46 Mus_musculus.transcript.tpm.SRR62.pickle
# -rw-r--r--  1 btsui users 4.8G Oct 28 05:17 Mus_musculus.transcript.tpm.SRR35.pickle
# -rw-r--r--  1 btsui users 1.2G Oct 28 05:06 Mus_musculus.transcript.tpm.SRR68.pickle
# -rw-r--r--  1 btsui users 488M Oct 28 04:53 Mus_musculus.transcript.tpm.SRR48.pickle
# -rw-r--r--  1 btsui users 4.9G Oct 28 04:47 Mus_musculus.transcript.tpm.SRR56.pickle
# -rw-r--r--  1 btsui users 2.3G Oct 28 04:22 Mus_musculus.transcript.tpm.SRR57.pickle
# -rw-r--r--  1 btsui users 2.8G Oct 28 04:00 Mus_musculus.transcript.tpm.SRR59.pickle
# -rw-r--r--  1 btsui users 1.4G Oct 28 03:57 Mus_musculus.transcript.tpm.SRR32.pickle
# -rw-r--r--  1 btsui users 224M Oct 28 03:54 Mus_musculus.transcript.tpm.SRR79.pickle
# -rw-r--r--  1 btsui users 3.6G Oct 28 03:51 Mus_musculus.transcript.tpm.SRR54.pickle
# -rw-r--r--  1 btsui users 3.9G Oct 28 03:40 Mus_musculus.transcript.tpm.SRR29.pickle
# -rw-r--r--  1 btsui users 3.4G Oct 28 03:26 Mus_musculus.transcript.tpm.SRR55.pickle
# -rw-r--r--  1 btsui users 2.7G Oct 28 03:09 Mus_musculus.transcript.tpm.SRR36.pickle
# -rw-r--r--  1 btsui users 820M Oct 28 02:55 Mus_musculus.transcript.tpm.SRR39.pickle
# -rw-r--r--  1 btsui users 1.3G Oct 28 02:45 Mus_musculus.transcript.tpm.SRR64.pickle
# -rw-r--r--  1 btsui users 254M Oct 28 02:44 Mus_musculus.transcript.tpm.SRR23.pickle
# -rw-r--r--  1 btsui users 203M Oct 28 02:41 Mus_musculus.transcript.tpm.SRR26.pickle
# -rw-r--r--  1 btsui users 1.1G Oct 28 02:38 Mus_musculus.transcript.tpm.SRR34.pickle
# -rw-r--r--  1 btsui users 3.8G Oct 28 02:37 Mus_musculus.transcript.tpm.SRR58.pickle
# -rw-r--r--  1 btsui users 393M Oct 28 02:30 Mus_musculus.transcript.tpm.SRR28.pickle
# -rw-r--r--  1 btsui users 2.6G Oct 28 02:26 Mus_musculus.transcript.tpm.SRR20.pickle
# -rw-r--r--  1 btsui users 2.0G Oct 28 02:25 Mus_musculus.transcript.tpm.SRR30.pickle
# -rw-r--r--  1 btsui users 445M Oct 28 02:00 Mus_musculus.transcript.tpm.SRR22.pickle
# -rw-r--r--  1 btsui users 751M Oct 28 01:55 Mus_musculus.transcript.tpm.SRR33.pickle
# -rw-r--r--  1 btsui users 2.6G Oct 28 01:54 Mus_musculus.transcript.tpm.SRR19.pickle
# -rw-r--r--  1 btsui users 2.6G Oct 28 01:53 Mus_musculus.transcript.tpm.SRR51.pickle
# -rw-r--r--  1 btsui users 208M Oct 28 01:45 Mus_musculus.transcript.tpm.SRR24.pickle
# -rw-r--r--  1 btsui users 1.3G Oct 28 01:43 Mus_musculus.transcript.tpm.SRR17.pickle
# -rw-r--r--  1 btsui users 2.3G Oct 28 01:27 Mus_musculus.transcript.tpm.SRR21.pickle
# -rw-r--r--  1 btsui users 831M Oct 28 01:23 Mus_musculus.transcript.tpm.SRR25.pickle
# -rw-r--r--  1 btsui users 4.0G Oct 28 01:22 Mus_musculus.transcript.tpm.SRR50.pickle
# -rw-r--r--  1 btsui users 166M Oct 28 01:13 Mus_musculus.transcript.tpm.SRR14.pickle
# -rw-r--r--  1 btsui users 429M Oct 28 01:11 Mus_musculus.transcript.tpm.SRR13.pickle
# -rw-r--r--  1 btsui users 627M Oct 28 01:06 Mus_musculus.transcript.tpm.SRR11.pickle
# -rw-r--r--  1 btsui users 3.0G Oct 28 00:59 Mus_musculus.transcript.tpm.SRR63.pickle
# -rw-r--r--  1 btsui users 5.6G Oct 28 00:57 Mus_musculus.transcript.tpm.SRR15.pickle
# -rw-r--r--  1 btsui users 1.5G Oct 28 00:36 Mus_musculus.transcript.tpm.SRR44.pickle
# -rw-r--r--  1 btsui users 4.3G Oct 28 00:22 Mus_musculus.transcript.tpm.SRR61.pickle
# -rw-r--r--  1 btsui users 1.1G Oct 28 00:19 Mus_musculus.transcript.tpm.SRR42.pickle
# -rw-r--r--  1 btsui users 2.9G Oct 28 00:06 Mus_musculus.transcript.tpm.SRR31.pickle
# -rw-r--r--  1 btsui users 703M Oct 27 23:54 Mus_musculus.transcript.tpm.SRR12.pickle
# -rw-r--r--  1 btsui users 1.4G Oct 27 23:45 Mus_musculus.transcript.tpm.SRR16.pickle
# -rw-r--r--  1 btsui users 2.5G Oct 27 23:32 Mus_musculus.transcript.tpm.SRR9.pickle
# -rw-r--r--  1 btsui users 1.7G Oct 27 23:29 Mus_musculus.transcript.tpm.ERR18.pickle
# -rw-r--r--  1 btsui users 288M Oct 27 23:29 Mus_musculus.transcript.tpm.SRR7.pickle
# -rw-r--r--  1 btsui users 938M Oct 27 23:25 Mus_musculus.transcript.tpm.SRR10.pickle
# -rw-r--r--  1 btsui users 431M Oct 27 23:14 Mus_musculus.transcript.tpm.SRR6.pickle
# -rw-r--r--  1 btsui users 583M Oct 27 23:09 Mus_musculus.transcript.tpm.ERR22.pickle
# -rw-r--r--  1 btsui users 884M Oct 27 23:09 Mus_musculus.transcript.tpm.SRR8.pickle
# -rw-r--r--  1 btsui users 535M Oct 27 23:03 Mus_musculus.transcript.tpm.SRR18.pickle
# -rw-r--r--  1 btsui users 2.4G Oct 27 23:01 Mus_musculus.transcript.tpm.ERR4.pickle
# -rw-r--r--  1 btsui users 560M Oct 27 22:58 Mus_musculus.transcript.tpm.SRR5.pickle
# -rw-r--r--  1 btsui users 1.2G Oct 27 22:57 Mus_musculus.transcript.tpm.ERR13.pickle
# -rw-r--r--  1 btsui users 284M Oct 27 22:52 Mus_musculus.transcript.tpm.SRR4.pickle
# -rw-r--r--  1 btsui users 242M Oct 27 22:48 Mus_musculus.transcript.tpm.SRR2.pickle
# -rw-r--r--  1 btsui users 586M Oct 27 22:46 Mus_musculus.transcript.tpm.SRR1.pickle
# -rw-r--r--  1 btsui users 138M Oct 27 22:43 Mus_musculus.transcript.tpm.ERR8.pickle
# -rw-r--r--  1 btsui users 132M Oct 27 22:42 Mus_musculus.transcript.tpm.ERR7.pickle
# -rw-r--r--  1 btsui users 1.1G Oct 27 22:40 Mus_musculus.transcript.tpm.ERR12.pickle
# -rw-r--r--  1 btsui users 238M Oct 27 22:39 Mus_musculus.transcript.tpm.SRR3.pickle
# -rw-r--r--  1 btsui users 259M Oct 27 22:36 Mus_musculus.transcript.tpm.SRR0.pickle
# -rw-r--r--  1 btsui users  60M Oct 27 22:33 Mus_musculus.transcript.tpm.ERR24.pickle
# -rw-r--r--  1 btsui users 1.1G Oct 27 22:32 Mus_musculus.transcript.tpm.ERR23.pickle
# -rw-r--r--  1 btsui users 303M Oct 27 22:31 Mus_musculus.transcript.tpm.ERR2.pickle
# -rw-r--r--  1 btsui users  18M Oct 27 22:28 Mus_musculus.transcript.tpm.ERR1.pickle
# -rw-r--r--  1 btsui users 765M Oct 27 22:27 Mus_musculus.transcript.tpm.ERR3.pickle
# -rw-r--r--  1 btsui users 1.5G Oct 27 22:27 Mus_musculus.transcript.tpm.ERR17.pickle
# -rw-r--r--  1 btsui users 514M Oct 27 22:20 Mus_musculus.transcript.tpm.ERR25.pickle
# -rw-r--r--  1 btsui users  36M Oct 27 22:18 Mus_musculus.transcript.tpm.ERR0.pickle
# -rw-r--r--  1 btsui users 271M Oct 27 22:17 Mus_musculus.transcript.tpm.DRR1.pickle
# -rw-r--r--  1 btsui users 1.5G Oct 27 22:14 Mus_musculus.transcript.tpm.ERR21.pickle
# -rw-r--r--  1 btsui users 4.7G Oct 27 22:13 Mus_musculus.transcript.tpm.SRR53.pickle
# -rw-r--r--  1 btsui users 1.1G Oct 27 22:09 Mus_musculus.transcript.tpm.ERR16.pickle
# -rw-r--r--  1 btsui users 433M Oct 27 21:57 Mus_musculus.transcript.tpm.ERR20.pickle
# -rw-r--r--  1 btsui users 133M Oct 27 21:56 Mus_musculus.transcript.tpm.ERR6.pickle
# -rw-r--r--  1 btsui users 341M Oct 27 21:54 Mus_musculus.transcript.tpm.ERR10.pickle
# -rw-r--r--  1 btsui users 304M Oct 27 21:52 Mus_musculus.transcript.tpm.ERR27.pickle
# -rw-r--r--  1 btsui users 1.1G Oct 27 21:50 Mus_musculus.transcript.tpm.ERR5.pickle
# -rw-r--r--  1 btsui users 1.1G Oct 27 21:48 Mus_musculus.transcript.tpm.ERR19.pickle
# -rw-r--r--  1 btsui users 2.3G Oct 27 21:36 Mus_musculus.transcript.tpm.ERR11.pickle
# -rw-r--r--  1 btsui users 1.1G Oct 27 21:36 Mus_musculus.transcript.tpm.ERR26.pickle
# -rw-r--r--  1 btsui users 210M Oct 27 21:22 Mus_musculus.transcript.tpm.ERR9.pickle
# -rw-r--r--  1 btsui users 218M Oct 27 21:19 Mus_musculus.transcript.tpm.ERR15.pickle
# -rw-r--r--  1 btsui users 721M Oct 27 21:17 Mus_musculus.transcript.tpm.DRR0.pickle
# -rw-r--r--  1 btsui users 692M Oct 27 21:17 Mus_musculus.transcript.tpm.ERR14.pickle
# -rw-r--r--  1 btsui users  31G Oct 27 20:53 Mus_musculus.transcript.est_counts.SRR65.pickle
# -rw-r--r--  1 btsui users  11G Oct 27 10:22 Mus_musculus.transcript.est_counts.SRR66.pickle
# -rw-r--r--  1 btsui users 497M Oct 27 10:15 Mus_musculus.transcript.est_counts.SRR74.pickle
# -rw-r--r--  1 btsui users 281M Oct 27 10:09 Mus_musculus.transcript.est_counts.SRR73.pickle
# -rw-r--r--  1 btsui users 4.0G Oct 27 10:06 Mus_musculus.transcript.est_counts.SRR72.pickle
# -rw-r--r--  1 btsui users 833M Oct 27 09:26 Mus_musculus.transcript.est_counts.SRR75.pickle
# -rw-r--r--  1 btsui users 908M Oct 27 09:18 Mus_musculus.transcript.est_counts.SRR76.pickle
# -rw-r--r--  1 btsui users 6.3G Oct 27 09:09 Mus_musculus.transcript.est_counts.SRR67.pickle
# -rw-r--r--  1 btsui users 130M Oct 27 08:56 Mus_musculus.transcript.est_counts.SRR78.pickle
# -rw-r--r--  1 btsui users 1.4G Oct 27 08:55 Mus_musculus.transcript.est_counts.SRR77.pickle
# -rw-r--r--  1 btsui users 9.2G Oct 27 08:48 Mus_musculus.transcript.est_counts.SRR60.pickle
# -rw-r--r--  1 btsui users 3.8G Oct 27 08:45 Mus_musculus.transcript.est_counts.SRR62.pickle
# -rw-r--r--  1 btsui users 3.0G Oct 27 08:40 Mus_musculus.transcript.est_counts.SRR40.pickle
# -rw-r--r--  1 btsui users 2.4G Oct 27 08:09 Mus_musculus.transcript.est_counts.SRR69.pickle
# -rw-r--r--  1 btsui users 4.8G Oct 27 08:08 Mus_musculus.transcript.est_counts.SRR35.pickle
# -rw-r--r--  1 btsui users 1.2G Oct 27 08:06 Mus_musculus.transcript.est_counts.SRR68.pickle
# -rw-r--r--  1 btsui users 488M Oct 27 07:53 Mus_musculus.transcript.est_counts.SRR48.pickle
# -rw-r--r--  1 btsui users 140M Oct 27 07:53 Mus_musculus.transcript.est_counts.SRR38.pickle
# -rw-r--r--  1 btsui users 389M Oct 27 07:51 Mus_musculus.transcript.est_counts.SRR41.pickle
# -rw-r--r--  1 btsui users 4.9G Oct 27 07:47 Mus_musculus.transcript.est_counts.SRR56.pickle
# -rw-r--r--  1 btsui users 837M Oct 27 07:46 Mus_musculus.transcript.est_counts.SRR43.pickle
# -rw-r--r--  1 btsui users 1.5G Oct 27 07:44 Mus_musculus.transcript.est_counts.SRR70.pickle
# -rw-r--r--  1 btsui users 5.2G Oct 27 07:38 Mus_musculus.transcript.est_counts.SRR52.pickle
# -rw-r--r--  1 btsui users  14M Oct 27 07:29 Mus_musculus.transcript.est_counts.SRR46.pickle
# -rw-r--r--  1 btsui users  19M Oct 27 07:28 Mus_musculus.transcript.est_counts.SRR45.pickle
# -rw-r--r--  1 btsui users 3.4G Oct 27 07:28 Mus_musculus.transcript.est_counts.SRR71.pickle
# -rw-r--r--  1 btsui users 2.3G Oct 27 07:19 Mus_musculus.transcript.est_counts.SRR57.pickle
# -rw-r--r--  1 btsui users 2.8G Oct 27 07:16 Mus_musculus.transcript.est_counts.SRR59.pickle
# -rw-r--r--  1 btsui users 1.4G Oct 27 06:57 Mus_musculus.transcript.est_counts.SRR32.pickle
# -rw-r--r--  1 btsui users  51M Oct 27 06:55 Mus_musculus.transcript.est_counts.SRR49.pickle
# -rw-r--r--  1 btsui users 224M Oct 27 06:55 Mus_musculus.transcript.est_counts.SRR79.pickle
# -rw-r--r--  1 btsui users 749M Oct 27 06:55 Mus_musculus.transcript.est_counts.SRR33.pickle
# -rw-r--r--  1 btsui users 5.6G Oct 27 06:53 Mus_musculus.transcript.est_counts.SRR15.pickle
# -rw-r--r--  1 btsui users 370M Oct 27 06:47 Mus_musculus.transcript.est_counts.SRR47.pickle
# -rw-r--r--  1 btsui users 3.4G Oct 27 06:47 Mus_musculus.transcript.est_counts.SRR55.pickle
# -rw-r--r--  1 btsui users 208M Oct 27 06:47 Mus_musculus.transcript.est_counts.SRR24.pickle
# -rw-r--r--  1 btsui users 1.3G Oct 27 06:45 Mus_musculus.transcript.est_counts.SRR17.pickle
# -rw-r--r--  1 btsui users 3.8G Oct 27 06:44 Mus_musculus.transcript.est_counts.SRR58.pickle
# -rw-r--r--  1 btsui users 3.9G Oct 27 06:42 Mus_musculus.transcript.est_counts.SRR29.pickle
# -rw-r--r--  1 btsui users 2.3G Oct 27 06:31 Mus_musculus.transcript.est_counts.SRR21.pickle
# -rw-r--r--  1 btsui users 254M Oct 27 06:13 Mus_musculus.transcript.est_counts.SRR23.pickle
# -rw-r--r--  1 btsui users 350M Oct 27 06:11 Mus_musculus.transcript.est_counts.SRR27.pickle
# -rw-r--r--  1 btsui users 3.0G Oct 27 06:07 Mus_musculus.transcript.est_counts.SRR63.pickle
# -rw-r--r--  1 btsui users 2.6G Oct 27 06:07 Mus_musculus.transcript.est_counts.SRR51.pickle
# -rw-r--r--  1 btsui users 675M Oct 27 06:07 Mus_musculus.transcript.est_counts.SRR37.pickle
# -rw-r--r--  1 btsui users 820M Oct 27 06:01 Mus_musculus.transcript.est_counts.SRR39.pickle
# -rw-r--r--  1 btsui users 1.2G Oct 27 06:00 Mus_musculus.transcript.est_counts.SRR64.pickle
# -rw-r--r--  1 btsui users 702M Oct 27 05:53 Mus_musculus.transcript.est_counts.SRR12.pickle
# -rw-r--r--  1 btsui users 2.6G Oct 27 05:52 Mus_musculus.transcript.est_counts.SRR20.pickle
# -rw-r--r--  1 btsui users 393M Oct 27 05:48 Mus_musculus.transcript.est_counts.SRR28.pickle
# -rw-r--r--  1 btsui users 1.4G Oct 27 05:46 Mus_musculus.transcript.est_counts.SRR16.pickle
# -rw-r--r--  1 btsui users 203M Oct 27 05:44 Mus_musculus.transcript.est_counts.SRR26.pickle
# -rw-r--r--  1 btsui users 1.1G Oct 27 05:42 Mus_musculus.transcript.est_counts.SRR34.pickle
# -rw-r--r--  1 btsui users 4.0G Oct 27 05:42 Mus_musculus.transcript.est_counts.SRR50.pickle
# -rw-r--r--  1 btsui users 4.3G Oct 27 05:35 Mus_musculus.transcript.est_counts.SRR61.pickle
# -rw-r--r--  1 btsui users 2.0G Oct 27 05:31 Mus_musculus.transcript.est_counts.SRR30.pickle
# -rw-r--r--  1 btsui users 288M Oct 27 05:31 Mus_musculus.transcript.est_counts.SRR7.pickle
# -rw-r--r--  1 btsui users 3.6G Oct 27 05:27 Mus_musculus.transcript.est_counts.SRR54.pickle
# -rw-r--r--  1 btsui users 2.6G Oct 27 05:24 Mus_musculus.transcript.est_counts.SRR19.pickle
# -rw-r--r--  1 btsui users 445M Oct 27 05:11 Mus_musculus.transcript.est_counts.SRR22.pickle
# -rw-r--r--  1 btsui users 2.5G Oct 27 05:06 Mus_musculus.transcript.est_counts.SRR9.pickle
# -rw-r--r--  1 btsui users 1.5G Oct 27 05:04 Mus_musculus.transcript.est_counts.SRR44.pickle
# -rw-r--r--  1 btsui users 831M Oct 27 04:57 Mus_musculus.transcript.est_counts.SRR25.pickle
# -rw-r--r--  1 btsui users 1.1G Oct 27 04:52 Mus_musculus.transcript.est_counts.ERR5.pickle
# -rw-r--r--  1 btsui users 1.1G Oct 27 04:48 Mus_musculus.transcript.est_counts.SRR42.pickle
# -rw-r--r--  1 btsui users 166M Oct 27 04:48 Mus_musculus.transcript.est_counts.SRR14.pickle
# -rw-r--r--  1 btsui users 2.7G Oct 27 04:47 Mus_musculus.transcript.est_counts.SRR36.pickle
# -rw-r--r--  1 btsui users 429M Oct 27 04:46 Mus_musculus.transcript.est_counts.SRR13.pickle
# -rw-r--r--  1 btsui users 627M Oct 27 04:41 Mus_musculus.transcript.est_counts.SRR11.pickle
# -rw-r--r--  1 btsui users 535M Oct 27 04:40 Mus_musculus.transcript.est_counts.SRR18.pickle
# -rw-r--r--  1 btsui users 2.3G Oct 27 04:40 Mus_musculus.transcript.est_counts.ERR11.pickle
# -rw-r--r--  1 btsui users 2.9G Oct 27 04:37 Mus_musculus.transcript.est_counts.SRR31.pickle
# -rw-r--r--  1 btsui users  18M Oct 27 04:35 Mus_musculus.transcript.est_counts.ERR1.pickle
# -rw-r--r--  1 btsui users 937M Oct 27 04:35 Mus_musculus.transcript.est_counts.SRR10.pickle
# -rw-r--r--  1 btsui users 765M Oct 27 04:34 Mus_musculus.transcript.est_counts.ERR3.pickle
# -rw-r--r--  1 btsui users  36M Oct 27 04:25 Mus_musculus.transcript.est_counts.ERR0.pickle
# -rw-r--r--  1 btsui users 271M Oct 27 04:24 Mus_musculus.transcript.est_counts.DRR1.pickle
# -rw-r--r--  1 btsui users 431M Oct 27 04:24 Mus_musculus.transcript.est_counts.SRR6.pickle
# -rw-r--r--  1 btsui users 4.7G Oct 27 04:22 Mus_musculus.transcript.est_counts.SRR53.pickle
# -rw-r--r--  1 btsui users 883M Oct 27 04:20 Mus_musculus.transcript.est_counts.SRR8.pickle
# -rw-r--r--  1 btsui users 284M Oct 27 04:18 Mus_musculus.transcript.est_counts.SRR4.pickle
# -rw-r--r--  1 btsui users 1.7G Oct 27 04:15 Mus_musculus.transcript.est_counts.ERR18.pickle
# -rw-r--r--  1 btsui users 242M Oct 27 04:13 Mus_musculus.transcript.est_counts.SRR2.pickle
# -rw-r--r--  1 btsui users 586M Oct 27 04:09 Mus_musculus.transcript.est_counts.SRR1.pickle
# -rw-r--r--  1 btsui users 560M Oct 27 04:08 Mus_musculus.transcript.est_counts.SRR5.pickle
# -rw-r--r--  1 btsui users 1.1G Oct 27 04:07 Mus_musculus.transcript.est_counts.ERR23.pickle
# -rw-r--r--  1 btsui users 238M Oct 27 04:03 Mus_musculus.transcript.est_counts.SRR3.pickle
# -rw-r--r--  1 btsui users 132M Oct 27 04:01 Mus_musculus.transcript.est_counts.ERR7.pickle
# -rw-r--r--  1 btsui users 259M Oct 27 04:00 Mus_musculus.transcript.est_counts.SRR0.pickle
# -rw-r--r--  1 btsui users 1.1G Oct 27 03:59 Mus_musculus.transcript.est_counts.ERR12.pickle
# -rw-r--r--  1 btsui users  60M Oct 27 03:57 Mus_musculus.transcript.est_counts.ERR24.pickle
# -rw-r--r--  1 btsui users 1.1G Oct 27 03:56 Mus_musculus.transcript.est_counts.ERR26.pickle
# -rw-r--r--  1 btsui users 506M Oct 27 03:56 Mus_musculus.transcript.est_counts.ERR25.pickle
# -rw-r--r--  1 btsui users 577M Oct 27 03:53 Mus_musculus.transcript.est_counts.ERR22.pickle
# -rw-r--r--  1 btsui users 1.5G Oct 27 03:51 Mus_musculus.transcript.est_counts.ERR21.pickle
# -rw-r--r--  1 btsui users 1.5G Oct 27 03:47 Mus_musculus.transcript.est_counts.ERR17.pickle
# -rw-r--r--  1 btsui users 2.4G Oct 27 03:46 Mus_musculus.transcript.est_counts.ERR4.pickle
# -rw-r--r--  1 btsui users 209M Oct 27 03:42 Mus_musculus.transcript.est_counts.ERR9.pickle
# -rw-r--r--  1 btsui users 218M Oct 27 03:40 Mus_musculus.transcript.est_counts.ERR15.pickle
# -rw-r--r--  1 btsui users 692M Oct 27 03:38 Mus_musculus.transcript.est_counts.ERR14.pickle
# -rw-r--r--  1 btsui users 429M Oct 27 03:35 Mus_musculus.transcript.est_counts.ERR20.pickle
# -rw-r--r--  1 btsui users 1.1G Oct 27 03:31 Mus_musculus.transcript.est_counts.ERR16.pickle
# -rw-r--r--  1 btsui users 304M Oct 27 03:30 Mus_musculus.transcript.est_counts.ERR27.pickle
# -rw-r--r--  1 btsui users 1.2G Oct 27 03:30 Mus_musculus.transcript.est_counts.ERR13.pickle
# -rw-r--r--  1 btsui users 1.1G Oct 27 03:26 Mus_musculus.transcript.est_counts.ERR19.pickle
# -rw-r--r--  1 btsui users 721M Oct 27 03:23 Mus_musculus.transcript.est_counts.DRR0.pickle
# -rw-r--r--  1 btsui users 133M Oct 27 03:19 Mus_musculus.transcript.est_counts.ERR6.pickle
# -rw-r--r--  1 btsui users 341M Oct 27 03:18 Mus_musculus.transcript.est_counts.ERR10.pickle
# -rw-r--r--  1 btsui users 303M Oct 27 03:18 Mus_musculus.transcript.est_counts.ERR2.pickle
# -rw-r--r--  1 btsui users 138M Oct 27 03:15 Mus_musculus.transcript.est_counts.ERR8.pickle
# -rw-r--r--  1 btsui users  16G Oct 27 03:13 Homo_sapiens.transcript.tpm.SRR77.pickle
# -rw-r--r--  1 btsui users 4.3M Oct 27 01:29 Homo_sapiens.transcript.tpm.SRR46.pickle
# -rw-r--r--  1 btsui users  16G Oct 27 01:29 Homo_sapiens.transcript.tpm.SRR59.pickle
# -rw-r--r--  1 btsui users 7.8G Oct 27 00:58 Homo_sapiens.transcript.tpm.SRR78.pickle
# -rw-r--r--  1 btsui users 3.7G Oct 27 00:53 Homo_sapiens.transcript.tpm.SRR76.pickle
# -rw-r--r--  1 btsui users 4.1G Oct 27 00:39 Homo_sapiens.transcript.tpm.SRR64.pickle
# -rw-r--r--  1 btsui users 3.5G Oct 27 00:29 Homo_sapiens.transcript.tpm.SRR68.pickle
# -rw-r--r--  1 btsui users 6.4G Oct 27 00:12 Homo_sapiens.transcript.tpm.SRR55.pickle
# -rw-r--r--  1 btsui users 5.0G Oct 27 00:08 Homo_sapiens.transcript.tpm.SRR67.pickle
# -rw-r--r--  1 btsui users 4.2G Oct 27 00:07 Homo_sapiens.transcript.tpm.SRR72.pickle
# -rw-r--r--  1 btsui users 1.3G Oct 26 23:55 Homo_sapiens.transcript.tpm.SRR43.pickle
# -rw-r--r--  1 btsui users 8.8G Oct 26 23:46 Homo_sapiens.transcript.tpm.SRR39.pickle
# -rw-r--r--  1 btsui users 1.8G Oct 26 23:39 Homo_sapiens.transcript.tpm.SRR75.pickle
# -rw-r--r--  1 btsui users 641M Oct 26 23:34 Homo_sapiens.transcript.tpm.SRR79.pickle
# -rw-r--r--  1 btsui users 2.2G Oct 26 23:32 Homo_sapiens.transcript.tpm.SRR37.pickle
# -rw-r--r--  1 btsui users 744M Oct 26 23:28 Homo_sapiens.transcript.tpm.SRR73.pickle
# -rw-r--r--  1 btsui users 4.3G Oct 26 23:27 Homo_sapiens.transcript.tpm.SRR70.pickle
# -rw-r--r--  1 btsui users 4.4G Oct 26 23:20 Homo_sapiens.transcript.tpm.SRR63.pickle
# -rw-r--r--  1 btsui users 2.0G Oct 26 23:18 Homo_sapiens.transcript.tpm.SRR66.pickle
# -rw-r--r--  1 btsui users 5.0G Oct 26 23:05 Homo_sapiens.transcript.tpm.SRR61.pickle
# -rw-r--r--  1 btsui users 1.5G Oct 26 22:58 Homo_sapiens.transcript.tpm.SRR69.pickle
# -rw-r--r--  1 btsui users 368M Oct 26 22:55 Homo_sapiens.transcript.tpm.SRR65.pickle
# -rw-r--r--  1 btsui users  11G Oct 26 22:51 Homo_sapiens.transcript.tpm.SRR35.pickle
# -rw-r--r--  1 btsui users 4.9G Oct 26 22:50 Homo_sapiens.transcript.tpm.SRR62.pickle
# -rw-r--r--  1 btsui users 526M Oct 26 22:49 Homo_sapiens.transcript.tpm.SRR13.pickle
# -rw-r--r--  1 btsui users 1.4G Oct 26 22:47 Homo_sapiens.transcript.tpm.SRR74.pickle
# -rw-r--r--  1 btsui users 7.8G Oct 26 22:43 Homo_sapiens.transcript.tpm.SRR53.pickle
# -rw-r--r--  1 btsui users 6.2G Oct 26 22:33 Homo_sapiens.transcript.tpm.SRR36.pickle
# -rw-r--r--  1 btsui users 3.2G Oct 26 22:31 Homo_sapiens.transcript.tpm.SRR32.pickle
# -rw-r--r--  1 btsui users 6.0G Oct 26 22:15 Homo_sapiens.transcript.tpm.SRR16.pickle
# -rw-r--r--  1 btsui users 3.9G Oct 26 22:10 Homo_sapiens.transcript.tpm.SRR60.pickle
# -rw-r--r--  1 btsui users  13G Oct 26 21:54 Homo_sapiens.transcript.tpm.SRR58.pickle
# -rw-r--r--  1 btsui users  11G Oct 26 21:52 Homo_sapiens.transcript.tpm.SRR52.pickle
# -rw-r--r--  1 btsui users 538M Oct 26 21:46 Homo_sapiens.transcript.tpm.SRR23.pickle
# -rw-r--r--  1 btsui users 1.5G Oct 26 21:43 Homo_sapiens.transcript.tpm.SRR48.pickle
# -rw-r--r--  1 btsui users 1.3G Oct 26 21:43 Homo_sapiens.transcript.tpm.SRR25.pickle
# -rw-r--r--  1 btsui users  12G Oct 26 21:36 Homo_sapiens.transcript.tpm.SRR29.pickle
# -rw-r--r--  1 btsui users 2.7G Oct 26 21:34 Homo_sapiens.transcript.tpm.SRR57.pickle
# -rw-r--r--  1 btsui users 1.8G Oct 26 21:34 Homo_sapiens.transcript.tpm.SRR47.pickle
# -rw-r--r--  1 btsui users 792M Oct 26 21:24 Homo_sapiens.transcript.tpm.SRR27.pickle
# -rw-r--r--  1 btsui users 1.6G Oct 26 21:19 Homo_sapiens.transcript.tpm.SRR71.pickle
# -rw-r--r--  1 btsui users 279M Oct 26 21:17 Homo_sapiens.transcript.tpm.SRR38.pickle
# -rw-r--r--  1 btsui users 832M Oct 26 21:14 Homo_sapiens.transcript.tpm.SRR28.pickle
# -rw-r--r--  1 btsui users 7.0G Oct 26 21:09 Homo_sapiens.transcript.tpm.SRR44.pickle
# -rw-r--r--  1 btsui users 803M Oct 26 21:05 Homo_sapiens.transcript.tpm.SRR22.pickle
# -rw-r--r--  1 btsui users 4.2G Oct 26 21:00 Homo_sapiens.transcript.tpm.SRR17.pickle
# -rw-r--r--  1 btsui users 8.9G Oct 26 20:47 Homo_sapiens.transcript.tpm.SRR51.pickle
# -rw-r--r--  1 btsui users 235M Oct 26 20:33 Homo_sapiens.transcript.tpm.SRR49.pickle
# -rw-r--r--  1 btsui users 1.3G Oct 26 20:31 Homo_sapiens.transcript.tpm.SRR41.pickle
# -rw-r--r--  1 btsui users 5.9G Oct 26 20:31 Homo_sapiens.transcript.tpm.SRR19.pickle
# -rw-r--r--  1 btsui users 7.2G Oct 26 20:24 Homo_sapiens.transcript.tpm.SRR56.pickle
# -rw-r--r--  1 btsui users 4.6G Oct 26 20:22 Homo_sapiens.transcript.tpm.SRR30.pickle
# -rw-r--r--  1 btsui users 9.6G Oct 26 20:21 Homo_sapiens.transcript.tpm.SRR42.pickle
# -rw-r--r--  1 btsui users  12G Oct 26 19:56 Homo_sapiens.transcript.tpm.SRR40.pickle
# -rw-r--r--  1 btsui users 8.2G Oct 26 19:51 Homo_sapiens.transcript.tpm.SRR50.pickle
# -rw-r--r--  1 btsui users 948M Oct 26 19:49 Homo_sapiens.transcript.tpm.SRR24.pickle
# -rw-r--r--  1 btsui users 215M Oct 26 19:44 Homo_sapiens.transcript.tpm.SRR26.pickle
# -rw-r--r--  1 btsui users 8.2G Oct 26 19:42 Homo_sapiens.transcript.tpm.SRR20.pickle
# -rw-r--r--  1 btsui users 145M Oct 26 19:39 Homo_sapiens.transcript.tpm.SRR14.pickle
# -rw-r--r--  1 btsui users 2.2G Oct 26 19:38 Homo_sapiens.transcript.tpm.SRR18.pickle
# -rw-r--r--  1 btsui users 4.8G Oct 26 19:25 Homo_sapiens.transcript.tpm.SRR34.pickle
# -rw-r--r--  1 btsui users 2.0G Oct 26 19:25 Homo_sapiens.transcript.tpm.SRR9.pickle
# -rw-r--r--  1 btsui users 699M Oct 26 19:06 Homo_sapiens.transcript.tpm.SRR7.pickle
# -rw-r--r--  1 btsui users 1.6G Oct 26 19:00 Homo_sapiens.transcript.tpm.SRR4.pickle
# -rw-r--r--  1 btsui users 9.5G Oct 26 18:59 Homo_sapiens.transcript.tpm.SRR54.pickle
# -rw-r--r--  1 btsui users 3.3G Oct 26 18:56 Homo_sapiens.transcript.tpm.SRR33.pickle
# -rw-r--r--  1 btsui users 8.7G Oct 26 18:53 Homo_sapiens.transcript.tpm.SRR31.pickle
# -rw-r--r--  1 btsui users 3.2G Oct 26 18:49 Homo_sapiens.transcript.tpm.SRR11.pickle
# -rw-r--r--  1 btsui users 3.5G Oct 26 18:47 Homo_sapiens.transcript.tpm.ERR18.pickle
# -rw-r--r--  1 btsui users 3.1G Oct 26 18:37 Homo_sapiens.transcript.tpm.SRR21.pickle
# -rw-r--r--  1 btsui users 7.1G Oct 26 18:29 Homo_sapiens.transcript.tpm.SRR12.pickle
# -rw-r--r--  1 btsui users 6.5G Oct 26 18:20 Homo_sapiens.transcript.tpm.ERR16.pickle
# -rw-r--r--  1 btsui users 1.1G Oct 26 18:19 Homo_sapiens.transcript.tpm.SRR6.pickle
# -rw-r--r--  1 btsui users 1.3G Oct 26 18:13 Homo_sapiens.transcript.tpm.SRR5.pickle
# -rw-r--r--  1 btsui users 617M Oct 26 18:03 Homo_sapiens.transcript.tpm.SRR1.pickle
# -rw-r--r--  1 btsui users  61M Oct 26 18:02 Homo_sapiens.transcript.tpm.SRR2.pickle
# -rw-r--r--  1 btsui users 3.4G Oct 26 18:02 Homo_sapiens.transcript.tpm.SRR15.pickle
# -rw-r--r--  1 btsui users 2.4G Oct 26 17:59 Homo_sapiens.transcript.tpm.SRR3.pickle
# -rw-r--r--  1 btsui users 774M Oct 26 17:59 Homo_sapiens.transcript.tpm.ERR26.pickle
# -rw-r--r--  1 btsui users 2.6G Oct 26 17:54 Homo_sapiens.transcript.tpm.ERR27.pickle
# -rw-r--r--  1 btsui users 4.1G Oct 26 17:45 Homo_sapiens.transcript.tpm.SRR10.pickle
# -rw-r--r--  1 btsui users 1.5G Oct 26 17:44 Homo_sapiens.transcript.tpm.SRR0.pickle
# -rw-r--r--  1 btsui users 416M Oct 26 17:41 Homo_sapiens.transcript.tpm.ERR11.pickle
# -rw-r--r--  1 btsui users 438M Oct 26 17:38 Homo_sapiens.transcript.tpm.ERR13.pickle
# -rw-r--r--  1 btsui users 4.8G Oct 26 17:36 Homo_sapiens.transcript.tpm.SRR8.pickle
# -rw-r--r--  1 btsui users 1.9G Oct 26 17:35 Homo_sapiens.transcript.tpm.ERR14.pickle
# -rw-r--r--  1 btsui users 2.7G Oct 26 17:34 Homo_sapiens.transcript.tpm.ERR15.pickle
# -rw-r--r--  1 btsui users 277M Oct 26 17:30 Homo_sapiens.transcript.tpm.ERR23.pickle
# -rw-r--r--  1 btsui users 4.4G Oct 26 17:27 Homo_sapiens.transcript.tpm.ERR25.pickle
# -rw-r--r--  1 btsui users 466M Oct 26 17:23 Homo_sapiens.transcript.tpm.ERR8.pickle
# -rw-r--r--  1 btsui users 937M Oct 26 17:20 Homo_sapiens.transcript.tpm.ERR22.pickle
# -rw-r--r--  1 btsui users 479M Oct 26 17:17 Homo_sapiens.transcript.tpm.ERR6.pickle
# -rw-r--r--  1 btsui users 187M Oct 26 17:14 Homo_sapiens.transcript.tpm.ERR4.pickle
# -rw-r--r--  1 btsui users 846M Oct 26 17:13 Homo_sapiens.transcript.tpm.ERR3.pickle
# -rw-r--r--  1 btsui users 1.4G Oct 26 17:12 Homo_sapiens.transcript.tpm.ERR19.pickle
# -rw-r--r--  1 btsui users 7.2G Oct 26 17:11 Homo_sapiens.transcript.tpm.ERR20.pickle
# -rw-r--r--  1 btsui users 4.5G Oct 26 17:07 Homo_sapiens.transcript.tpm.ERR10.pickle
# -rw-r--r--  1 btsui users 788M Oct 26 17:06 Homo_sapiens.transcript.tpm.ERR12.pickle
# -rw-r--r--  1 btsui users 4.1G Oct 26 17:01 Homo_sapiens.transcript.tpm.ERR17.pickle
# -rw-r--r--  1 btsui users 584M Oct 26 17:01 Homo_sapiens.transcript.tpm.ERR2.pickle
# -rw-r--r--  1 btsui users 915M Oct 26 16:57 Homo_sapiens.transcript.tpm.ERR1.pickle
# -rw-r--r--  1 btsui users 167M Oct 26 16:55 Homo_sapiens.transcript.tpm.ERR24.pickle
# -rw-r--r--  1 btsui users 3.7G Oct 26 16:53 Homo_sapiens.transcript.tpm.ERR21.pickle
# -rw-r--r--  1 btsui users 148M Oct 26 16:50 Homo_sapiens.transcript.tpm.ERR0.pickle
# -rw-r--r--  1 btsui users  37M Oct 26 16:49 Homo_sapiens.transcript.tpm.DRR1.pickle
# -rw-r--r--  1 btsui users 3.5G Oct 26 16:49 Homo_sapiens.transcript.tpm.DRR0.pickle
# -rw-r--r--  1 btsui users 799M Oct 26 16:35 Homo_sapiens.transcript.tpm.ERR7.pickle
# -rw-r--r--  1 btsui users 768M Oct 26 16:30 Homo_sapiens.transcript.tpm.ERR9.pickle
# -rw-r--r--  1 btsui users 528M Oct 26 16:29 Homo_sapiens.transcript.tpm.ERR5.pickle
# -rw-r--r--  1 btsui users  32G Oct 26 16:24 Homo_sapiens.transcript.est_counts.SRR77.pickle
# -rw-r--r--  1 btsui users 8.4G Oct 26 16:00 Homo_sapiens.transcript.est_counts.SRR72.pickle
# -rw-r--r--  1 btsui users  16G Oct 26 15:32 Homo_sapiens.transcript.est_counts.SRR78.pickle
# -rw-r--r--  1 btsui users  10G Oct 26 15:23 Homo_sapiens.transcript.est_counts.SRR67.pickle
# -rw-r--r--  1 btsui users 6.9G Oct 26 15:22 Homo_sapiens.transcript.est_counts.SRR68.pickle
# -rw-r--r--  1 btsui users  26G Oct 26 14:56 Homo_sapiens.transcript.est_counts.SRR58.pickle
# -rw-r--r--  1 btsui users    0 Oct 26 14:51 Homo_sapiens.transcript.est_counts.SRR29.pickle
# -rw-r--r--  1 btsui users 8.6G Oct 26 14:45 Homo_sapiens.transcript.est_counts.SRR70.pickle
# -rw-r--r--  1 btsui users  31G Oct 26 14:44 Homo_sapiens.transcript.est_counts.SRR59.pickle
# -rw-r--r--  1 btsui users  22G Oct 26 14:36 Homo_sapiens.transcript.est_counts.SRR35.pickle
# -rw-r--r--  1 btsui users  18G Oct 26 14:15 Homo_sapiens.transcript.est_counts.SRR39.pickle
# -rw-r--r--  1 btsui users  17G Oct 26 13:40 Homo_sapiens.transcript.est_counts.SRR20.pickle
# -rw-r--r--  1 btsui users  15G Oct 26 13:35 Homo_sapiens.transcript.est_counts.SRR56.pickle
# -rw-r--r--  1 btsui users  13G Oct 26 13:28 Homo_sapiens.transcript.est_counts.SRR36.pickle
# -rw-r--r--  1 btsui users 6.3G Oct 26 13:14 Homo_sapiens.transcript.est_counts.SRR32.pickle
# -rw-r--r--  1 btsui users  12G Oct 26 13:04 Homo_sapiens.transcript.est_counts.SRR19.pickle
# -rw-r--r--  1 btsui users  18G Oct 26 12:54 Homo_sapiens.transcript.est_counts.SRR51.pickle
# -rw-r--r--  1 btsui users  19G Oct 26 12:49 Homo_sapiens.transcript.est_counts.SRR54.pickle
# -rw-r--r--  1 btsui users  16G Oct 26 12:46 Homo_sapiens.transcript.est_counts.SRR53.pickle
# -rw-r--r--  1 btsui users  20G Oct 26 12:46 Homo_sapiens.transcript.est_counts.SRR42.pickle
# -rw-r--r--  1 btsui users  23G Oct 26 12:20 Homo_sapiens.transcript.est_counts.SRR40.pickle
# -rw-r--r--  1 btsui users  21G Oct 26 11:54 Homo_sapiens.transcript.est_counts.SRR52.pickle
# -rw-r--r--  1 btsui users  17G Oct 26 11:45 Homo_sapiens.transcript.est_counts.SRR50.pickle
# -rw-r--r--  1 btsui users  14G Oct 26 11:41 Homo_sapiens.transcript.est_counts.SRR44.pickle
# -rw-r--r--  1 btsui users  18G Oct 26 11:29 Homo_sapiens.transcript.est_counts.SRR31.pickle
# -rw-r--r--  1 btsui users 8.8G Oct 26 11:07 Homo_sapiens.transcript.est_counts.ERR25.pickle
# -rw-r--r--  1 btsui users  13G Oct 26 10:51 Homo_sapiens.transcript.est_counts.ERR16.pickle
# -rw-r--r--  1 btsui users 6.3G Oct 26 10:50 Homo_sapiens.transcript.est_counts.SRR11.pickle
# -rw-r--r--  1 btsui users 8.2G Oct 26 10:50 Homo_sapiens.transcript.est_counts.SRR10.pickle
# -rw-r--r--  1 btsui users  15G Oct 26 10:36 Homo_sapiens.transcript.est_counts.ERR20.pickle
# -rw-r--r--  1 btsui users 6.8G Oct 26 10:27 Homo_sapiens.transcript.est_counts.SRR15.pickle
# -rw-r--r--  1 btsui users  15G Oct 26 10:27 Homo_sapiens.transcript.est_counts.SRR12.pickle
# -rw-r--r--  1 btsui users 9.6G Oct 26 10:17 Homo_sapiens.transcript.est_counts.SRR8.pickle
# -rw-r--r--  1 btsui users 8.2G Oct 26 10:11 Homo_sapiens.transcript.est_counts.ERR17.pickle
# -rw-r--r--  1 btsui users 2.0G Oct 26 10:04 Homo_sapiens.transcript.est_counts.SRR9.pickle
# -rw-r--r--  1 btsui users 7.3G Oct 26 00:05 Homo_sapiens.transcript.est_counts.SRR76.pickle
# -rw-r--r--  1 btsui users 8.7G Oct 26 00:04 Homo_sapiens.transcript.est_counts.SRR63.pickle
# -rw-r--r--  1 btsui users  13G Oct 25 23:57 Homo_sapiens.transcript.est_counts.SRR55.pickle
# -rw-r--r--  1 btsui users 9.6G Oct 25 23:46 Homo_sapiens.transcript.est_counts.SRR62.pickle
# -rw-r--r--  1 btsui users  10G Oct 25 23:41 Homo_sapiens.transcript.est_counts.SRR61.pickle
# -rw-r--r--  1 btsui users 8.2G Oct 25 23:39 Homo_sapiens.transcript.est_counts.SRR64.pickle
# -rw-r--r--  1 btsui users 3.5G Oct 25 23:39 Homo_sapiens.transcript.est_counts.SRR75.pickle
# -rw-r--r--  1 btsui users 356M Oct 25 23:35 Homo_sapiens.transcript.est_counts.SRR65.pickle
# -rw-r--r--  1 btsui users 1.3G Oct 25 23:34 Homo_sapiens.transcript.est_counts.SRR74.pickle
# -rw-r--r--  1 btsui users 737M Oct 25 23:29 Homo_sapiens.transcript.est_counts.SRR73.pickle
# -rw-r--r--  1 btsui users 2.9G Oct 25 23:29 Homo_sapiens.transcript.est_counts.SRR69.pickle
# -rw-r--r--  1 btsui users 639M Oct 25 23:26 Homo_sapiens.transcript.est_counts.SRR79.pickle
# -rw-r--r--  1 btsui users 7.6G Oct 25 23:21 Homo_sapiens.transcript.est_counts.SRR60.pickle
# -rw-r--r--  1 btsui users 5.4G Oct 25 23:19 Homo_sapiens.transcript.est_counts.SRR57.pickle
# -rw-r--r--  1 btsui users 2.6G Oct 25 23:19 Homo_sapiens.transcript.est_counts.SRR43.pickle
# -rw-r--r--  1 btsui users 3.9G Oct 25 23:17 Homo_sapiens.transcript.est_counts.SRR66.pickle
# -rw-r--r--  1 btsui users 4.4G Oct 25 23:16 Homo_sapiens.transcript.est_counts.SRR37.pickle
# -rw-r--r--  1 btsui users 4.3M Oct 25 23:12 Homo_sapiens.transcript.est_counts.SRR46.pickle
# -rw-r--r--  1 btsui users  12G Oct 25 23:09 Homo_sapiens.transcript.est_counts.SRR16.pickle
# -rw-r--r--  1 btsui users 2.6G Oct 25 23:04 Homo_sapiens.transcript.est_counts.SRR25.pickle
# -rw-r--r--  1 btsui users 3.4G Oct 25 22:59 Homo_sapiens.transcript.est_counts.SRR47.pickle
# -rw-r--r--  1 btsui users 1.6G Oct 25 22:57 Homo_sapiens.transcript.est_counts.SRR71.pickle
# -rw-r--r--  1 btsui users 1.1G Oct 25 22:55 Homo_sapiens.transcript.est_counts.SRR23.pickle
# -rw-r--r--  1 btsui users 3.0G Oct 25 22:55 Homo_sapiens.transcript.est_counts.SRR48.pickle
# -rw-r--r--  1 btsui users 1.7G Oct 25 22:52 Homo_sapiens.transcript.est_counts.SRR28.pickle
# -rw-r--r--  1 btsui users 279M Oct 25 22:50 Homo_sapiens.transcript.est_counts.SRR38.pickle
# -rw-r--r--  1 btsui users 1.6G Oct 25 22:47 Homo_sapiens.transcript.est_counts.SRR27.pickle
# -rw-r--r--  1 btsui users 9.2G Oct 25 22:46 Homo_sapiens.transcript.est_counts.SRR30.pickle
# -rw-r--r--  1 btsui users 4.3G Oct 25 22:41 Homo_sapiens.transcript.est_counts.SRR18.pickle
# -rw-r--r--  1 btsui users 8.4G Oct 25 22:40 Homo_sapiens.transcript.est_counts.SRR17.pickle
# -rw-r--r--  1 btsui users 1.6G Oct 25 22:39 Homo_sapiens.transcript.est_counts.SRR22.pickle
# -rw-r--r--  1 btsui users 2.5G Oct 25 22:36 Homo_sapiens.transcript.est_counts.SRR41.pickle
# -rw-r--r--  1 btsui users 145M Oct 25 22:23 Homo_sapiens.transcript.est_counts.SRR14.pickle
# -rw-r--r--  1 btsui users 9.6G Oct 25 22:23 Homo_sapiens.transcript.est_counts.SRR34.pickle
# -rw-r--r--  1 btsui users 6.5G Oct 25 22:22 Homo_sapiens.transcript.est_counts.SRR33.pickle
# -rw-r--r--  1 btsui users 6.2G Oct 25 22:21 Homo_sapiens.transcript.est_counts.SRR21.pickle
# -rw-r--r--  1 btsui users 1.9G Oct 25 22:13 Homo_sapiens.transcript.est_counts.SRR24.pickle
# -rw-r--r--  1 btsui users 215M Oct 25 22:00 Homo_sapiens.transcript.est_counts.SRR26.pickle
# -rw-r--r--  1 btsui users 463M Oct 25 21:55 Homo_sapiens.transcript.est_counts.SRR49.pickle
# -rw-r--r--  1 btsui users 526M Oct 25 21:48 Homo_sapiens.transcript.est_counts.SRR13.pickle
# -rw-r--r--  1 btsui users 7.3G Oct 25 21:37 Homo_sapiens.transcript.est_counts.ERR21.pickle
# -rw-r--r--  1 btsui users 3.2G Oct 25 21:36 Homo_sapiens.transcript.est_counts.SRR4.pickle
# -rw-r--r--  1 btsui users 2.6G Oct 25 21:30 Homo_sapiens.transcript.est_counts.ERR27.pickle
# -rw-r--r--  1 btsui users 699M Oct 25 21:30 Homo_sapiens.transcript.est_counts.SRR7.pickle
# -rw-r--r--  1 btsui users  61M Oct 25 21:26 Homo_sapiens.transcript.est_counts.SRR2.pickle
# -rw-r--r--  1 btsui users 1.3G Oct 25 21:26 Homo_sapiens.transcript.est_counts.SRR5.pickle
# -rw-r--r--  1 btsui users 9.0G Oct 25 21:24 Homo_sapiens.transcript.est_counts.ERR10.pickle
# -rw-r--r--  1 btsui users 6.9G Oct 25 21:23 Homo_sapiens.transcript.est_counts.ERR18.pickle
# -rw-r--r--  1 btsui users 2.1G Oct 25 21:22 Homo_sapiens.transcript.est_counts.SRR6.pickle
# -rw-r--r--  1 btsui users 4.8G Oct 25 21:22 Homo_sapiens.transcript.est_counts.SRR3.pickle
# -rw-r--r--  1 btsui users 6.9G Oct 25 21:18 Homo_sapiens.transcript.est_counts.DRR0.pickle
# -rw-r--r--  1 btsui users 5.4G Oct 25 21:15 Homo_sapiens.transcript.est_counts.ERR15.pickle
# -rw-r--r--  1 btsui users 2.9G Oct 25 21:15 Homo_sapiens.transcript.est_counts.SRR0.pickle
# -rw-r--r--  1 btsui users 1.2G Oct 25 21:12 Homo_sapiens.transcript.est_counts.SRR1.pickle
# -rw-r--r--  1 btsui users 3.7G Oct 25 21:12 Homo_sapiens.transcript.est_counts.ERR14.pickle
# -rw-r--r--  1 btsui users 1.6G Oct 25 21:06 Homo_sapiens.transcript.est_counts.ERR26.pickle
# -rw-r--r--  1 btsui users 936M Oct 25 21:03 Homo_sapiens.transcript.est_counts.ERR22.pickle
# -rw-r--r--  1 btsui users 2.8G Oct 25 21:01 Homo_sapiens.transcript.est_counts.ERR19.pickle
# -rw-r--r--  1 btsui users 273M Oct 25 21:01 Homo_sapiens.transcript.est_counts.ERR23.pickle
# -rw-r--r--  1 btsui users 825M Oct 25 20:59 Homo_sapiens.transcript.est_counts.ERR11.pickle
# -rw-r--r--  1 btsui users 166M Oct 25 20:58 Homo_sapiens.transcript.est_counts.ERR24.pickle
# -rw-r--r--  1 btsui users 925M Oct 25 20:57 Homo_sapiens.transcript.est_counts.ERR8.pickle
# -rw-r--r--  1 btsui users 868M Oct 25 20:57 Homo_sapiens.transcript.est_counts.ERR13.pickle
# -rw-r--r--  1 btsui users 1.8G Oct 25 20:56 Homo_sapiens.transcript.est_counts.ERR1.pickle
# -rw-r--r--  1 btsui users 1.7G Oct 25 20:55 Homo_sapiens.transcript.est_counts.ERR3.pickle
# -rw-r--r--  1 btsui users 1.5G Oct 25 20:54 Homo_sapiens.transcript.est_counts.ERR9.pickle
# -rw-r--r--  1 btsui users 1.6G Oct 25 20:54 Homo_sapiens.transcript.est_counts.ERR7.pickle
# -rw-r--r--  1 btsui users 1.6G Oct 25 20:54 Homo_sapiens.transcript.est_counts.ERR12.pickle
# -rw-r--r--  1 btsui users 1.2G Oct 25 20:53 Homo_sapiens.transcript.est_counts.ERR2.pickle
# -rw-r--r--  1 btsui users 952M Oct 25 20:52 Homo_sapiens.transcript.est_counts.ERR6.pickle
# -rw-r--r--  1 btsui users 1.1G Oct 25 20:51 Homo_sapiens.transcript.est_counts.ERR5.pickle
# -rw-r--r--  1 btsui users 367M Oct 25 20:49 Homo_sapiens.transcript.est_counts.ERR4.pickle
# -rw-r--r--  1 btsui users 289M Oct 25 20:48 Homo_sapiens.transcript.est_counts.ERR0.pickle
# -rw-r--r--  1 btsui users  36M Oct 25 20:47 Homo_sapiens.transcript.est_counts.DRR1.pickle
# drwxr-xr-x 20 btsui users 128K Oct 25 20:45 ..

# %%
# !ls -laht /nrnb/users/btsui/Data/all_seq/rnaseq_merged_chunks/ | wc -l
# Out:
# 43

# %%
# !cat  all_seq.sh
# Out:
# #! /bin/bash
# # Which shell to use
# #$ -S /bin/bash
# # Transfer all variables to job script (e.g. PATH, LD_LIBRARY_PATH, etc.)
# #$ -V
# # Queue to schedule jobs to
# ## -l h_rt=0:30:00
# ## -l u14
# #$ -l h_vmem=10g
# #$ -l long
# #$ -l tmpfree=2T
# #$ -l h=!(nrnb-5-0|nrnb-5-1|nrnb-5-2|nrnb-5-3|nrnb-5-4|nrnb-5-5|nrnb-5-6)
# # Directory to send stdout and stderr
# ## -o /dev/null
# ## -e /dev/null
# #$ -o /nrnb/users/btsui/Data/all_seq/log_rnaseq/
# #$ -e  /nrnb/users/btsui/Data/all_seq/log_rnaseq/
# # Run in current working directory
# #$ -cwd
# # Array job 14175
# #$ -t 1-6
# ## -p -0
# #$ -r y
# #$ -tc 20
# #$ -pe smp 1
# #SRR_FTP="/cellar/users/btsui/Data/SRA/META/processing.srr"
# hostname
# export PATH=/cellar/users/btsui/anaconda2/bin/:$PATH
# /cellar/users/btsui/anaconda2/bin/python -u /cellar/users/btsui/Project/METAMAP/notebook/RapMapTest/Pipelines/RNAseq/run_one.py $SGE_TASK_ID
