# %% [markdown]
# **Feel free to contact me at**: btsui@eng.ucsd.edu if you have any question.
#
#
# # In short
#
#
# Skymap is a standalone database that offers:
# 1. **a single data matrix** for each omic layer for each species that spans >200k sequencing runs from all the public studies, which is done by reprocessing **petabytes** worth of sequencing data. Here is how much published data are deposited in SRA:
# ![alt text](./Figures/sra_data_availability.png "Logo Title Text 1")**And here is how much data we have processed from SRA:**
# ![alt text](./Figures/sra_data_processed.png)
# 2. **a biological metadata file** that describe the relationships between the sequencing runs and also the keywords extracted from over **3 million** freetext annotations using NLP.
# 3. **a techinical metadata file** that describe the relationships between the sequencing runs.
#
#
# **Where they can all fit into your personal computer.**
#
# **If you intend to run the examples, please first download the data from here:**
# * https://www.synapse.org/skymap (take < 3 minutes to set up the account).
#
#
# Part of this work was presented on ISMB: https://github.com/brianyiktaktsui/Skymap/blob/master/ISMB_poster_Skymap.pdf
# # Examples: simple code to analyze big data
#
#
# ## High resolution mouse developmental hierachy map
# [jupyter notebook link](https://github.com/brianyiktaktsui/Skymap/blob/master/jupyter-notebooks/clean_notebooks/TemporalQuery_V4_all_clean.ipynb
# )
#
# Aggregating many studies (node) to form a smooth mouse developmental hierachy map. By integrating the vast amount of public data, we can cover many developmental time points, which sometime we can see a more transient expression dynamics both across tissues and within tissues over developmental time course.
#
# Each componenet represent a tissue. Each node represent a particular study at a particular time unit. The color is base on the developmental time extracted from experimental annotation using regex. The node size represent the # of sequencing runs in that particulr time point and study. Each edge represent a differentiate-to or part-of relationship.
# ![alt text](./Figures/heirachy_time.png "Logo Title Text 1")
# And you can easily overlay gene expression level on top of it. As an example, Tp53 expression is known to be tightly regulated in development. Let's look at the dynamic of Tp53 expression over time and spatial locations in the following plot.
# ![alt_text](./Figures/heirachy_Trp53.png "tp53")
#
# ## Locating  SNP and correlating with different data layers
# [jupyter notebook link](https://github.com/brianyiktaktsui/Skymap/blob/master/FindStudiesWithBrafV600Mutated.ipynb)
# ## Simple RNAseq data slicing and hypothesis testing
# https://github.com/brianyiktaktsui/Skymap/blob/master/DataSlicingExample.ipynb
#
# [Check here for more example notebooks](https://github.com/brianyiktaktsui/Skymap/tree/master/jupyter-notebooks
# )
#
# The code for the pipelines is here:
# https://github.com/brianyiktaktsui/Skymap/tree/master/code
#
# Skymap is still in Beta V0.0. [Please feel free to leave comments](https://www.synapse.org/#!Synapse:syn11415602/discussion/default) and suggestions!!! We would love to hear feedbacks from you.

# %% [markdown]
# ## Methods (Manuscripts)
#
# | Description | URL to google docs | github|
# | ---: | ---: | ---: |
# | Metaanalysis using NLP (Metamap) and reprocessed RNAseq data | https://docs.google.com/document/d/1_nES7vroX7lCwf5NSNBVZ1k2iubYm5wLeFqusq5aZuk |  |
# | Deep biomedical named entity recognition NLP engine | https://docs.google.com/document/d/1_nES7vroX7lCwf5NSNBVZ1k2iubYm5wLeFqusq5aZuk | https://github.com/brianyiktaktsui/DEEP_NLP |

# %% [markdown]
# #  Pipeline
#
# If you happen to want to dig into the gut and gore make a copy of the pipeline, the code are documented as the followings

# %% [markdown]
# ### Download, parse and merge SRA META DATA
#
# |Steps | Code| Input description|Input dir|Output description|Output dir| Timing| Python version|
# |---- | ----| ----|----|----|----| ----|
# |download SRA metadata | http://localhost:6001/notebooks/Project/METAMAP/notebook/RapMapTest/Pipelines/Update_SRA_meta_data/pull_SRA_meta.ipynb |none, download from web||SRA meta data| /nrnb/users/btsui/tmp/SRA_META/| 30 mins| Python 3 |
# |parse SRA metadata | ./SRA_META/SRAManager.py |  SRA files in XML formats|/nrnb/users/btsui/tmp/SRA_META/| list of pandas series containing list of (SRS,attribute, freetext) | /cellar/users/btsui/Data/nrnb01_nobackup/tmp/METAMAP//splittedInput_SRAMangaer_SRA_META/| 20 mins| Python 2|
# |merge SRA metadata | ./SRA_META/SRAmerge.py | list of pandas series containing list of (SRS,attribute, freetext) |/cellar/users/btsui/Data/nrnb01_nobackup/tmp/METAMAP//splittedInput_SRAMangaer_SRA_META/(allSRS.pickle,allSRX.pickle) |all SRA SRS biospecieman annotation in allSRS.pickle and allSRX.pickle  | /cellar/users/btsui/Data/nrnb01_nobackup/METAMAP/ | 10 mins| Python 3|
#
#
# old directory: /cellar/users/btsui/Project/METAMAP/code/metamap/

# %% [markdown]
# ### To update the SNP pipeline:
#
# The way I organized the code is trying to keep the code as simple as possible.
# For each pipeline, it has 6 scripts, <500 lines each to ensure readability. Run each pipeliine starting with calcuate_uprocessed.py, which calculate the number of files still require for processing.
#
#
# |Pipeline | Code| Input description|Input dir|Output description|Output dir| Timing|
# |---- | ----| ----|----|----|----| ----|
# |SNP extraction | ./Pipelines/snp/calculate_unprocessed.py|
# |calculating reads coverage | ./Pipelines/chip/calculate_unprocessed.py|
# |RNAseq quantification| ./Pipelines/RNAseq/calculate_unprocessed.py |
# |merge SNP alignment statistics | http://localhost:6001/notebooks/Project/METAMAP/notebook/RapMapTest/Analysis/merge_variant_aligning_statistics.ipynb |
# | merge SNP data | http://localhost:6001/notebooks/Project/METAMAP/notebook/RapMapTest/XGS_WGS/ParseAndMergeBamReadCount.ipynb |
#
#
#  Details of benchmarking against TCGA are located at:
#
# http://localhost:6001/notebooks/Project/METAMAP/notebook/RapMapTest/XGS_WGS/README_TCGA_benchmark.ipynb
#
# However, due to the fact where patients allele informations are protected, we are not providing the allellic read counts for TCGA.

# %% [markdown]
# ## Acknowledgement
#
#
# Please considering citing if you are using Skymap. (doi:10.7303/syn11415602)
#
# (https://github.com/brianyiktaktsui/Skymap/blob/master/ISMB_poster_Skymap.pdf)
#
#
# Acknowledgement: We want to thank for the advice and resources from Dr. Hannah Carter (my PI), Dr. Jill Mesirov,Dr. Trey Ideker and Shamin Mollah. We also want to thank Dr. Ruben Arbagayen, Dr. Nate Lewis for their suggestion.
# The method will soon be posted in bioarchive. Also, we want to thank the Sage Bio Network for hosting the data. We also thank to thank the NCBI for holding all the published raw reads at  [Sequnece Read Archive](https://www.ncbi.nlm.nih.gov/sra).
# Grant money that make this work possible: NIH DP5OD017937,GM103504
#
#
# Term of use: Use Skymap however you want. Just dont sue me, I have no money.
#
#
#
# For why I named it Skymap, I forgot.
#
# ## Data format and coding style
#
# The storage is in python pandas pickle format. Therefore, the only packges you need to load in the data is numpy and pandas, the backbone of data analysis in python. We keep the process of data loading as lean as possible. Less code means less bugs and less errors. For now, Skymap is geared towards ML/data science folks who are hungry for the vast amount of data and ain't afraid of coding. I will port the data to native HDF5 format to reduce platform dependency once I get a chance.
#
# I tried to keep the code and parameters to be lean and self-explanatory for your reference.

# %%
# !git pull
# Out:
# remote: Counting objects: 3, done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (3/3), done.
# From github.com:brianyiktaktsui/AllPipes
#    c39cddd..c9c1567  master     -> origin/master
# Modified              [ Can now UnJustify! ]justify   ^_ Go To Lineaster' of github.com:brianyiktaktsui/AllPipes[ line 1/8 (12%), col 1/61 (1%), char 0/288 (0%) ]

# %%
# !jupyter nbconvert --to markdown README.ipynb
# !git add README.md ./Figures/sra_data_processed.png #./jupyter-notebooks/clean_notebooks/*
# !git commit -m "updated: README"
# !git push
# Out:
# [NbConvertApp] Converting notebook README.ipynb to markdown
# [NbConvertApp] Writing 9264 bytes to README.md
# [master 095908e] updated: README
#  1 file changed, 22 insertions(+), 15 deletions(-)
# Counting objects: 3, done.
# Delta compression using up to 96 threads.
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 818 bytes | 0 bytes/s, done.
# Total 3 (delta 2), reused 0 (delta 0)
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# remote: This repository moved. Please use the new location:
# remote:   git@github.com:brianyiktaktsui/Skymap.git
# To git@github.com:brianyiktaktsui/AllPipes.git
#    f29590d..095908e  master -> master

# %%
#

# %%
# !find . -name '*.ipynb' | xargs git add

# %%
# !git commit -m "updated: new files"
# !git push
# Out:
# [master e68c517] updated: new files
#  218 files changed, 228461 insertions(+)
#  create mode 100644 .ipynb_checkpoints/README-checkpoint.ipynb
#  create mode 100644 .ipynb_checkpoints/Untitled-checkpoint.ipynb
#  create mode 100644 Analysis/.ipynb_checkpoints/AllSeqBySpecies-checkpoint.ipynb
#  create mode 100644 Analysis/.ipynb_checkpoints/CheckCompressionRatio-checkpoint.ipynb
#  create mode 100644 Analysis/.ipynb_checkpoints/CheckForStromalMarkers-checkpoint.ipynb
#  create mode 100644 Analysis/.ipynb_checkpoints/CompareTCGA_alignment_w_mine_pipe-checkpoint.ipynb
#  create mode 100644 Analysis/.ipynb_checkpoints/ExampleSNPSliceForJisoo-checkpoint.ipynb
#  create mode 100644 Analysis/.ipynb_checkpoints/FindStudiesWithBrafV600Mutated_with_entire_demo-checkpoint.ipynb
#  create mode 100644 Analysis/.ipynb_checkpoints/GetDataSpace-checkpoint.ipynb
#  create mode 100644 Analysis/.ipynb_checkpoints/README-checkpoint.ipynb
#  create mode 100644 Analysis/.ipynb_checkpoints/SingleCellLeukemia-checkpoint.ipynb
#  create mode 100644 Analysis/.ipynb_checkpoints/Untitled-checkpoint.ipynb
#  create mode 100644 Analysis/.ipynb_checkpoints/analyzeAnlignmentStatistics-checkpoint.ipynb
#  create mode 100644 Analysis/.ipynb_checkpoints/checkBasicStat-checkpoint.ipynb
#  create mode 100644 Analysis/.ipynb_checkpoints/checkMicrobiome-checkpoint.ipynb
#  create mode 100644 Analysis/.ipynb_checkpoints/data_count-checkpoint.ipynb
#  create mode 100644 Analysis/.ipynb_checkpoints/getBasicDataCounting_AllelicReadCount-checkpoint.ipynb
#  create mode 100644 Analysis/.ipynb_checkpoints/getBasicDataCounting_AllelicReadCount_PrimaryVsCelllines-checkpoint.ipynb
#  create mode 100644 Analysis/.ipynb_checkpoints/getBasicDataCounting_coverage-checkpoint.ipynb
#  create mode 100644 Analysis/.ipynb_checkpoints/getBasicDataCounting_coverage_byExperiments-checkpoint.ipynb
#  create mode 100644 Analysis/.ipynb_checkpoints/merge_variant_aligning_statistics-checkpoint.ipynb
#  create mode 100644 Analysis/.ipynb_checkpoints/retrieveDisease-checkpoint.ipynb
#  create mode 100644 Analysis/AllSeqBySpecies.ipynb
#  create mode 100644 Analysis/CheckCompressionRatio.ipynb
#  create mode 100644 Analysis/CheckForStromalMarkers.ipynb
#  create mode 100644 Analysis/CompareTCGA_alignment_w_mine_pipe.ipynb
#  create mode 100644 Analysis/ExampleSNPSliceForJisoo.ipynb
#  create mode 100644 Analysis/FindStudiesWithBrafV600Mutated_with_entire_demo.ipynb
#  create mode 100644 Analysis/GetDataSpace.ipynb
#  create mode 100644 Analysis/README.ipynb
#  create mode 100644 Analysis/SingleCellLeukemia.ipynb
#  create mode 100644 Analysis/Untitled.ipynb
#  create mode 100644 Analysis/analyzeAnlignmentStatistics.ipynb
#  create mode 100644 Analysis/checkBasicStat.ipynb
#  create mode 100644 Analysis/checkMicrobiome.ipynb
#  create mode 100644 Analysis/data_count.ipynb
#  create mode 100644 Analysis/getBasicDataCounting_AllelicReadCount.ipynb
#  create mode 100644 Analysis/getBasicDataCounting_AllelicReadCount_PrimaryVsCelllines.ipynb
#  create mode 100644 Analysis/getBasicDataCounting_coverage.ipynb
#  create mode 100644 Analysis/getBasicDataCounting_coverage_byExperiments.ipynb
#  create mode 100644 Analysis/merge_variant_aligning_statistics.ipynb
#  create mode 100644 Analysis/retrieveDisease.ipynb
#  create mode 100644 Analysis/singleCellAnalysis/.ipynb_checkpoints/AnalyzeDataLandscape-checkpoint.ipynb
#  create mode 100644 Analysis/singleCellAnalysis/AnalyzeDataLandscape.ipynb
#  create mode 100644 AnalyzeReferences/.ipynb_checkpoints/testQuasiMap-checkpoint.ipynb
#  create mode 100644 AnalyzeReferences/testQuasiMap.ipynb
#  create mode 100644 BS_aling/.ipynb_checkpoints/GenerateReference-checkpoint.ipynb
#  create mode 100644 BS_aling/.ipynb_checkpoints/TestRunOneFile-checkpoint.ipynb
#  create mode 100644 BS_aling/.ipynb_checkpoints/Untitled-checkpoint.ipynb
#  create mode 100644 BS_aling/GenerateReference.ipynb
#  create mode 100644 BS_aling/TestRunOneFile.ipynb
#  create mode 100644 BS_aling/Untitled.ipynb
#  create mode 100644 Chip-seq/.ipynb_checkpoints/BuildEmptyPickles-checkpoint.ipynb
#  create mode 100644 Chip-seq/.ipynb_checkpoints/BuildGenomes-checkpoint.ipynb
#  create mode 100644 Chip-seq/.ipynb_checkpoints/ConvertBedsToWigs-checkpoint.ipynb
#  create mode 100644 Chip-seq/.ipynb_checkpoints/CorrelateData-checkpoint.ipynb
#  create mode 100644 Chip-seq/.ipynb_checkpoints/DownloadAllEpigenomeRoadmap-checkpoint.ipynb
#  create mode 100644 Chip-seq/.ipynb_checkpoints/Process_One-checkpoint.ipynb
#  create mode 100644 Chip-seq/.ipynb_checkpoints/TryAnalyzingTheRegions-checkpoint.ipynb
#  create mode 100644 Chip-seq/.ipynb_checkpoints/Untitled-checkpoint.ipynb
#  create mode 100644 Chip-seq/.ipynb_checkpoints/Untitled1-checkpoint.ipynb
#  create mode 100644 Chip-seq/.ipynb_checkpoints/Untitled2-checkpoint.ipynb
#  create mode 100644 Chip-seq/.ipynb_checkpoints/alignSingleEndedBowtie-checkpoint.ipynb
#  create mode 100644 Chip-seq/.ipynb_checkpoints/old_chunkUpGenomeInto100MB-checkpoint.ipynb
#  create mode 100644 Chip-seq/.ipynb_checkpoints/parse_sam_input_single_ended-checkpoint.ipynb
#  create mode 100644 Chip-seq/.ipynb_checkpoints/test_count-checkpoint.ipynb
#  create mode 100644 Chip-seq/BuildEmptyPickles.ipynb
#  create mode 100644 Chip-seq/BuildGenomes.ipynb
#  create mode 100644 Chip-seq/ConvertBedsToWigs.ipynb
#  create mode 100644 Chip-seq/CorrelateData.ipynb
#  create mode 100644 Chip-seq/DownloadAllEpigenomeRoadmap.ipynb
#  create mode 100644 Chip-seq/Process_One.ipynb
#  create mode 100644 Chip-seq/TryAnalyzingTheRegions.ipynb
#  create mode 100644 Chip-seq/Untitled.ipynb
#  create mode 100644 Chip-seq/Untitled1.ipynb
#  create mode 100644 Chip-seq/Untitled2.ipynb
#  create mode 100644 Chip-seq/alignSingleEndedBowtie.ipynb
#  create mode 100644 Chip-seq/old_chunkUpGenomeInto100MB.ipynb
#  create mode 100644 Chip-seq/parse_sam_input_single_ended.ipynb
#  create mode 100644 Chip-seq/test_count.ipynb
#  create mode 100644 DownloadGenome/.ipynb_checkpoints/CheckMicrobiome-checkpoint.ipynb
#  create mode 100644 DownloadGenome/.ipynb_checkpoints/ExtractCleanFastas-checkpoint.ipynb
#  create mode 100644 DownloadGenome/.ipynb_checkpoints/PullAllReferenceGenomes_release_90-Copy1-checkpoint.ipynb
#  create mode 100644 DownloadGenome/.ipynb_checkpoints/PullAllReferenceGenomes_release_90-checkpoint.ipynb
#  create mode 100644 DownloadGenome/.ipynb_checkpoints/PullAllReference_Genomes_plant-checkpoint.ipynb
#  create mode 100644 DownloadGenome/.ipynb_checkpoints/PullAllReference_Transcriptome_plant-checkpoint.ipynb
#  create mode 100644 DownloadGenome/.ipynb_checkpoints/PullAllReference_Transcritpomes_release_90-checkpoint.ipynb
#  create mode 100644 DownloadGenome/.ipynb_checkpoints/Untitled-checkpoint.ipynb
#  create mode 100644 DownloadGenome/.ipynb_checkpoints/old_PullAllReferenceGenomes_bacteria-checkpoint.ipynb
#  create mode 100644 DownloadGenome/CheckMicrobiome.ipynb
#  create mode 100644 DownloadGenome/ExtractCleanFastas.ipynb
#  create mode 100644 DownloadGenome/PullAllReferenceGenomes_release_90-Copy1.ipynb
#  create mode 100644 DownloadGenome/PullAllReferenceGenomes_release_90.ipynb
#  create mode 100644 DownloadGenome/PullAllReference_Genomes_plant.ipynb
#  create mode 100644 DownloadGenome/PullAllReference_Transcriptome_plant.ipynb
#  create mode 100644 DownloadGenome/PullAllReference_Transcritpomes_release_90.ipynb
#  create mode 100644 DownloadGenome/Untitled.ipynb
#  create mode 100644 DownloadGenome/old_PullAllReferenceGenomes_bacteria.ipynb
#  create mode 100644 Microbiome/.ipynb_checkpoints/generateViralReferenceFromMetaphlan-checkpoint.ipynb
#  create mode 100644 Microbiome/.ipynb_checkpoints/mergeNCBIViralGenome-checkpoint.ipynb
#  create mode 100644 Microbiome/generateViralReferenceFromMetaphlan.ipynb
#  create mode 100644 Microbiome/mergeNCBIViralGenome.ipynb
#  create mode 100644 NLP_spacy/.ipynb_checkpoints/README-checkpoint.ipynb
#  create mode 100644 NLP_spacy/.ipynb_checkpoints/Untitled-checkpoint.ipynb
#  create mode 100644 NLP_spacy/.ipynb_checkpoints/Untitled1-checkpoint.ipynb
#  create mode 100644 NLP_spacy/.ipynb_checkpoints/Untitled2-checkpoint.ipynb
#  create mode 100644 NLP_spacy/.ipynb_checkpoints/Untitled3-checkpoint.ipynb
#  create mode 100644 NLP_spacy/README.ipynb
#  create mode 100644 NLP_spacy/Untitled.ipynb
#  create mode 100644 NLP_spacy/Untitled1.ipynb
#  create mode 100644 NLP_spacy/Untitled2.ipynb
#  create mode 100644 NLP_spacy/Untitled3.ipynb
#  create mode 100644 Pipelines/.ipynb_checkpoints/Untitled-checkpoint.ipynb
#  create mode 100644 Pipelines/RNAseq/.ipynb_checkpoints/Untitled-checkpoint.ipynb
#  create mode 100644 Pipelines/RNAseq/Untitled.ipynb
#  create mode 100644 Pipelines/Update_SRA_meta_data/.ipynb_checkpoints/ExportForMetamap-checkpoint.ipynb
#  create mode 100644 Pipelines/Update_SRA_meta_data/.ipynb_checkpoints/NCIMetaDataMapping-checkpoint.ipynb
#  create mode 100755 Pipelines/Update_SRA_meta_data/.ipynb_checkpoints/annotate_SRA_meta_data-checkpoint.ipynb
#  create mode 100644 Pipelines/Update_SRA_meta_data/.ipynb_checkpoints/pull_SRA_meta-checkpoint.ipynb
#  create mode 100644 Pipelines/Update_SRA_meta_data/ExportForMetamap.ipynb
#  create mode 100644 Pipelines/Update_SRA_meta_data/NCIMetaDataMapping.ipynb
#  create mode 100755 Pipelines/Update_SRA_meta_data/annotate_SRA_meta_data.ipynb
#  create mode 100644 Pipelines/Update_SRA_meta_data/pull_SRA_meta.ipynb
#  create mode 100644 Pipelines/chip/.ipynb_checkpoints/Untitled-checkpoint.ipynb
#  create mode 100644 Pipelines/chip/Untitled.ipynb
#  create mode 100644 Pipelines/synapse_upload/.ipynb_checkpoints/uploadSnpToSynpase-checkpoint.ipynb
#  create mode 100644 Pipelines/synapse_upload/uploadSnpToSynpase.ipynb
#  create mode 100644 README.ipynb
#  create mode 100644 RNAseq/.ipynb_checkpoints/generateReferences-checkpoint.ipynb
#  create mode 100644 RNAseq/generateReferences.ipynb
#  create mode 100644 Skymap_legacy-master/DataSlicingExample.ipynb
#  create mode 100644 Skymap_legacy-master/FindStudiesWithBrafV600Mutated.ipynb
#  create mode 100644 Skymap_legacy-master/Load_RawMetaData.ipynb
#  create mode 100644 Skymap_legacy-master/jupyter-notebooks/clean_notebooks/AllSeqBySpecies.ipynb
#  create mode 100644 Skymap_legacy-master/jupyter-notebooks/clean_notebooks/CompareTCGA_alignment_w_mine_pipe.ipynb
#  create mode 100644 Skymap_legacy-master/jupyter-notebooks/clean_notebooks/TemporalQuery_V4_all_clean.ipynb
#  create mode 100644 Untitled.ipynb
#  create mode 100644 XGS_WGS/.ipynb_checkpoints/CheckVCF-checkpoint.ipynb
#  create mode 100644 XGS_WGS/.ipynb_checkpoints/CompareTCGA_alignment_w_mine_pipe-checkpoint.ipynb
#  create mode 100644 XGS_WGS/.ipynb_checkpoints/Compare_TCGA_RNAseq_WXS-checkpoint.ipynb
#  create mode 100644 XGS_WGS/.ipynb_checkpoints/Compare_TCGA_RNAseq_WXS_IDH1_only-checkpoint.ipynb
#  create mode 100644 XGS_WGS/.ipynb_checkpoints/Compare_TCGA_RNAseq_WXS_allOverlapSites-checkpoint.ipynb
#  create mode 100644 XGS_WGS/.ipynb_checkpoints/FindStudiesWithBrafV600Mutated-checkpoint.ipynb
#  create mode 100644 XGS_WGS/.ipynb_checkpoints/GenerateEmptyPicklesForEachSpecies-checkpoint.ipynb
#  create mode 100644 XGS_WGS/.ipynb_checkpoints/MaskingGenomeWithSnp_Specie-checkpoint.ipynb
#  create mode 100644 XGS_WGS/.ipynb_checkpoints/MaskingGenomeWithSnp_human-checkpoint.ipynb
#  create mode 100644 XGS_WGS/.ipynb_checkpoints/MergeViralAndBacterial-checkpoint.ipynb
#  create mode 100644 XGS_WGS/.ipynb_checkpoints/ParseAndMergeBamReadCount-checkpoint.ipynb
#  create mode 100644 XGS_WGS/.ipynb_checkpoints/Pull_TCGA_meta_data-checkpoint.ipynb
#  create mode 100644 XGS_WGS/.ipynb_checkpoints/README_TCGA_benchmark-checkpoint.ipynb
#  create mode 100644 XGS_WGS/.ipynb_checkpoints/Scratch-checkpoint.ipynb
#  create mode 100644 XGS_WGS/.ipynb_checkpoints/Untitled-checkpoint.ipynb
#  create mode 100644 XGS_WGS/.ipynb_checkpoints/Untitled1-checkpoint.ipynb
#  create mode 100644 XGS_WGS/.ipynb_checkpoints/Untitled2-checkpoint.ipynb
#  create mode 100644 XGS_WGS/.ipynb_checkpoints/basicQualityCheck-checkpoint.ipynb
#  create mode 100644 XGS_WGS/.ipynb_checkpoints/conver_bed_to_uscs-checkpoint.ipynb
#  create mode 100644 XGS_WGS/.ipynb_checkpoints/correlateSites__MyPipe_and_TcgaPipe-checkpoint.ipynb
#  create mode 100644 XGS_WGS/.ipynb_checkpoints/downloadingVCFs-checkpoint.ipynb
#  create mode 100644 XGS_WGS/.ipynb_checkpoints/identify_TCGA_WXS_RNAseq_runs-checkpoint.ipynb
#  create mode 100644 XGS_WGS/.ipynb_checkpoints/mergeBamReadCount.v2-checkpoint.ipynb
#  create mode 100644 XGS_WGS/.ipynb_checkpoints/mergeTCGA_VCF-checkpoint.ipynb
#  create mode 100644 XGS_WGS/.ipynb_checkpoints/old_BuildReferenceWithMicrobes-checkpoint.ipynb
#  create mode 100644 XGS_WGS/.ipynb_checkpoints/old_ParseAndMergeBamReadCount.v2-checkpoint.ipynb
#  create mode 100644 XGS_WGS/.ipynb_checkpoints/old_downloadTCGA_LGG-checkpoint.ipynb
#  create mode 100644 XGS_WGS/.ipynb_checkpoints/scratch_delete-checkpoint.ipynb
#  create mode 100644 XGS_WGS/.ipynb_checkpoints/testOne-checkpoint.ipynb
#  create mode 100644 XGS_WGS/CheckVCF.ipynb
#  create mode 100644 XGS_WGS/Compare_TCGA_RNAseq_WXS.ipynb
#  create mode 100644 XGS_WGS/Compare_TCGA_RNAseq_WXS_IDH1_only.ipynb
#  create mode 100644 XGS_WGS/Compare_TCGA_RNAseq_WXS_allOverlapSites.ipynb
#  create mode 100644 XGS_WGS/ExtractFromTCGA/.ipynb_checkpoints/extract_allelic_read_counts-checkpoint.ipynb
#  create mode 100644 XGS_WGS/ExtractFromTCGA/.ipynb_checkpoints/mergeBamReadCountFiles-checkpoint.ipynb
#  create mode 100644 XGS_WGS/ExtractFromTCGA/.ipynb_checkpoints/scratch-checkpoint.ipynb
#  create mode 100644 XGS_WGS/ExtractFromTCGA/.ipynb_checkpoints/submitJobForAllleleExtraction-checkpoint.ipynb
#  create mode 100644 XGS_WGS/ExtractFromTCGA/extract_allelic_read_counts.ipynb
#  create mode 100644 XGS_WGS/ExtractFromTCGA/mergeBamReadCountFiles.ipynb
#  create mode 100644 XGS_WGS/ExtractFromTCGA/scratch.ipynb
#  create mode 100644 XGS_WGS/ExtractFromTCGA/submitJobForAllleleExtraction.ipynb
#  create mode 100644 XGS_WGS/FindStudiesWithBrafV600Mutated.ipynb
#  create mode 100644 XGS_WGS/GenerateEmptyPicklesForEachSpecies.ipynb
#  create mode 100644 XGS_WGS/MaskingGenomeWithSnp_Specie.ipynb
#  create mode 100644 XGS_WGS/MaskingGenomeWithSnp_human.ipynb
#  create mode 100644 XGS_WGS/MergeViralAndBacterial.ipynb
#  create mode 100644 XGS_WGS/ParseAndMergeBamReadCount.ipynb
#  create mode 100644 XGS_WGS/Pull_TCGA_meta_data.ipynb
#  create mode 100644 XGS_WGS/README_TCGA_benchmark.ipynb
#  create mode 100644 XGS_WGS/Scratch.ipynb
#  create mode 100644 XGS_WGS/TestPipeline/.ipynb_checkpoints/compareAgainstSomaticMutations-checkpoint.ipynb
#  create mode 100644 XGS_WGS/TestPipeline/.ipynb_checkpoints/correlateMyAllelicReadCountWithTCGA_VCF_Df-checkpoint.ipynb
#  create mode 100644 XGS_WGS/TestPipeline/.ipynb_checkpoints/extractAllelicFractionFromTCGA-checkpoint.ipynb
#  create mode 100644 XGS_WGS/TestPipeline/.ipynb_checkpoints/mergeBamReadCountFiles-checkpoint.ipynb
#  create mode 100644 XGS_WGS/TestPipeline/.ipynb_checkpoints/mutationCalling-checkpoint.ipynb
#  create mode 100644 XGS_WGS/TestPipeline/.ipynb_checkpoints/old_AllelicFractionCountCorrelation-checkpoint.ipynb
#  create mode 100644 XGS_WGS/TestPipeline/.ipynb_checkpoints/submitJobForAllleleExtraction-checkpoint.ipynb
#  create mode 100644 XGS_WGS/TestPipeline/.ipynb_checkpoints/submitJobsForTiming-checkpoint.ipynb
#  create mode 100644 XGS_WGS/TestPipeline/compareAgainstSomaticMutations.ipynb
#  create mode 100644 XGS_WGS/TestPipeline/correlateMyAllelicReadCountWithTCGA_VCF_Df.ipynb
#  create mode 100644 XGS_WGS/TestPipeline/extractAllelicFractionFromTCGA.ipynb
#  create mode 100644 XGS_WGS/TestPipeline/mergeBamReadCountFiles.ipynb
#  create mode 100644 XGS_WGS/TestPipeline/mutationCalling.ipynb
#  create mode 100644 XGS_WGS/TestPipeline/old_AllelicFractionCountCorrelation.ipynb
#  create mode 100644 XGS_WGS/TestPipeline/submitJobForAllleleExtraction.ipynb
#  create mode 100644 XGS_WGS/TestPipeline/submitJobsForTiming.ipynb
#  create mode 100644 XGS_WGS/Untitled.ipynb
#  create mode 100644 XGS_WGS/Untitled1.ipynb
#  create mode 100644 XGS_WGS/Untitled2.ipynb
#  create mode 100644 XGS_WGS/basicQualityCheck.ipynb
#  create mode 100644 XGS_WGS/conver_bed_to_uscs.ipynb
#  create mode 100644 XGS_WGS/correlateSites__MyPipe_and_TcgaPipe.ipynb
#  create mode 100644 XGS_WGS/downloadingVCFs.ipynb
#  create mode 100644 XGS_WGS/identify_TCGA_WXS_RNAseq_runs.ipynb
#  create mode 100644 XGS_WGS/mergeBamReadCount.v2.ipynb
#  create mode 100644 XGS_WGS/mergeTCGA_VCF.ipynb
#  create mode 100644 XGS_WGS/old_BuildReferenceWithMicrobes.ipynb
#  create mode 100644 XGS_WGS/old_ParseAndMergeBamReadCount.v2.ipynb
#  create mode 100644 XGS_WGS/old_downloadTCGA_LGG.ipynb
#  create mode 100644 XGS_WGS/scratch_delete.ipynb
#  create mode 100644 XGS_WGS/testOne.ipynb
# Counting objects: 208, done.
# Delta compression using up to 96 threads.
# Compressing objects: 100% (207/207), done.
# Writing objects: 100% (208/208), 2.37 MiB | 3.66 MiB/s, done.
# Total 208 (delta 70), reused 0 (delta 0)
# remote: Resolving deltas: 100% (70/70), done.
# remote: This repository moved. Please use the new location:
# remote:   git@github.com:brianyiktaktsui/Skymap.git
# To git@github.com:brianyiktaktsui/AllPipes.git
#    095908e..e68c517  master -> master

# %%
# !git config --global push.default simple

# %%
#!ls ./Figures/sra_data_processed.png

# %%
# !pwd
# Out:
# /cellar/users/btsui/Project/METAMAP/notebook/RapMapTest
