# %%
# TO UPDATE SRA META DATA
# Out:
#   File "<ipython-input-1-ba099d6ee9e8>", line 4
#     |Steps | Code| Input description|Input dir|Output description|Output dir| Timing|
#     ^
# SyntaxError: invalid syntax
