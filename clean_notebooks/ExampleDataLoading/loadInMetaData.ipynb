# %% [markdown]
# ### load in technical meta data
#
# For more information about the IDs being used, please reference the follow site:
#
# https://www.ncbi.nlm.nih.gov/books/NBK56913/

# %%
import pandas as pd
# Out:
# /cellar/users/btsui/anaconda3/envs/deep_nlp_cpu/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
sra_dump_pickle_dir='/cellar/users/btsui/Data/SRA/DUMP/sra_dump.pickle'
technical_meta_data_df=pd.read_pickle(sra_dump_pickle_dir)

# %%
technical_meta_data_df.shape
# Out:
# (3763299, 23)

# %%
technical_meta_data_df.head(n=30)
# Out:
#            Member_Name  Experiment      Sample      Study       Spots  \
# Run
# SRR2401865     default  SRX1244330  SRS1068422          -      2800.0
# SRR2401866     default  SRX1244331  SRS1068421          -      5082.0
# SRR2401867     default  SRX1244332  SRS1068420          -      6169.0
# SRR2401868     default  SRX1244333  SRS1068419          -      8102.0
# SRR2401869     default  SRX1244334  SRS1068418          -      4971.0
# SRR2401870     default  SRX1244335  SRS1068417          -      1131.0
# SRR2401871     default  SRX1244336  SRS1068416          -      1025.0
# SRR2401872     default  SRX1244337  SRS1068415          -      1084.0
# SRR2407111     default  SRX1245627  SRS1068991          -      6273.0
# DRR000001      default   DRX000001   DRS000001  DRP000001  10148174.0
# DRR000002      default   DRX000002   DRS000002  DRP000002   8316737.0
# DRR000003      default   DRX000003   DRS000003  DRP000003   6459732.0
# DRR000004      default   DRX000003   DRS000003  DRP000003   6061180.0
# DRR000005      default   DRX000003   DRS000003  DRP000003   6040762.0
# DRR000006      default   DRX000003   DRS000003  DRP000003   5936619.0
# DRR000007      default   DRX000003   DRS000003  DRP000003   3503763.0
# DRR000363      default   DRX000003   DRS000003  DRP000003  43900909.0
# DRR000364      default   DRX000003   DRS000003  DRP000003  44984884.0
# DRR000365      default   DRX000003   DRS000003  DRP000003  45416179.0
# DRR000366      default   DRX000003   DRS000003  DRP000003  44948037.0
# DRR000008      default   DRX000004   DRS000004  DRP000004  19153889.0
# DRR000009      default   DRX000004   DRS000004  DRP000004  17668118.0
# DRR000010      default   DRX000004   DRS000004  DRP000004  18079621.0
# DRR000011      default   DRX000005   DRS000005  DRP000005  15788579.0
# DRR000012      default   DRX000005   DRS000005  DRP000005  15075547.0
# DRR000013      default   DRX000005   DRS000005  DRP000005  15490013.0
# DRR000014      default   DRX000006   DRS000006  DRP000006  16388392.0
# DRR000015      default   DRX000006   DRS000006  DRP000006  15287389.0
# DRR000016      default   DRX000006   DRS000006  DRP000006  15445050.0
# DRR000017      default   DRX000007   DRS000007  DRP000007  19115295.0
#
#                    Bases Status                              ScientificName  \
# Run
# SRR2401865  1.416405e+06   live                             soil_metagenome
# SRR2401866  2.563605e+06   live                             soil_metagenome
# SRR2401867  3.175528e+06   live                             soil_metagenome
# SRR2401868  4.266915e+06   live                             soil_metagenome
# SRR2401869  2.519200e+06   live                             soil_metagenome
# SRR2401870  5.513300e+05   live                             soil_metagenome
# SRR2401871  5.334680e+05   live                             soil_metagenome
# SRR2401872  5.568810e+05   live                             soil_metagenome
# SRR2407111  3.250384e+06   live                             soil_metagenome
# DRR000001   7.306685e+08   live      Bacillus_subtilis_subsp._natto_BEST195
# DRR000002   5.988051e+08   live  Bacillus_subtilis_subsp._subtilis_str._168
# DRR000003   2.325504e+08   live                                Homo_sapiens
# DRR000004   2.182025e+08   live                                Homo_sapiens
# DRR000005   2.174674e+08   live                                Homo_sapiens
# DRR000006   2.137183e+08   live                                Homo_sapiens
# DRR000007   1.261355e+08   live                                Homo_sapiens
# DRR000363   1.580433e+09   live                                Homo_sapiens
# DRR000364   1.619456e+09   live                                Homo_sapiens
# DRR000365   1.634982e+09   live                                Homo_sapiens
# DRR000366   1.618129e+09   live                                Homo_sapiens
# DRR000008   6.895400e+08   live                                Homo_sapiens
# DRR000009   6.360522e+08   live                                Homo_sapiens
# DRR000010   6.508664e+08   live                                Homo_sapiens
# DRR000011   5.683888e+08   live                                Homo_sapiens
# DRR000012   5.427197e+08   live                                Homo_sapiens
# DRR000013   5.576405e+08   live                                Homo_sapiens
# DRR000014   5.899821e+08   live                                Homo_sapiens
# DRR000015   5.503460e+08   live                                Homo_sapiens
# DRR000016   5.560218e+08   live                                Homo_sapiens
# DRR000017   6.881506e+08   live                                Homo_sapiens
#
#            LibraryStrategy LibraryLayout    ...     proj_accession_Published  \
# Run                                         ...
# SRR2401865        AMPLICON        SINGLE    ...                   2015-09-20
# SRR2401866        AMPLICON        SINGLE    ...                   2015-09-20
# SRR2401867        AMPLICON        SINGLE    ...                   2015-09-20
# SRR2401868        AMPLICON        SINGLE    ...                   2015-09-20
# SRR2401869        AMPLICON        SINGLE    ...                   2015-09-20
# SRR2401870        AMPLICON        SINGLE    ...                   2015-09-20
# SRR2401871        AMPLICON        SINGLE    ...                   2015-09-20
# SRR2401872        AMPLICON        SINGLE    ...                   2015-09-20
# SRR2407111        AMPLICON        SINGLE    ...                   2015-09-20
# DRR000001              WGS        PAIRED    ...                   2010-03-24
# DRR000002              WGS        PAIRED    ...                   2010-03-24
# DRR000003          FL-cDNA        SINGLE    ...                   2010-10-14
# DRR000004          FL-cDNA        SINGLE    ...                   2010-10-14
# DRR000005          FL-cDNA        SINGLE    ...                   2010-10-14
# DRR000006          FL-cDNA        SINGLE    ...                   2010-10-14
# DRR000007          FL-cDNA        SINGLE    ...                   2010-10-14
# DRR000363          FL-cDNA        SINGLE    ...                   2010-10-14
# DRR000364          FL-cDNA        SINGLE    ...                   2010-10-14
# DRR000365          FL-cDNA        SINGLE    ...                   2010-10-14
# DRR000366          FL-cDNA        SINGLE    ...                   2010-10-14
# DRR000008          FL-cDNA        SINGLE    ...                   2010-10-14
# DRR000009          FL-cDNA        SINGLE    ...                   2010-10-14
# DRR000010          FL-cDNA        SINGLE    ...                   2010-10-14
# DRR000011          FL-cDNA        SINGLE    ...                   2010-10-14
# DRR000012          FL-cDNA        SINGLE    ...                   2010-10-14
# DRR000013          FL-cDNA        SINGLE    ...                   2010-10-14
# DRR000014          FL-cDNA        SINGLE    ...                   2010-10-14
# DRR000015          FL-cDNA        SINGLE    ...                   2010-10-14
# DRR000016          FL-cDNA        SINGLE    ...                   2010-10-14
# DRR000017          FL-cDNA        SINGLE    ...                   2010-10-14
#
#            proj_accession_Received proj_accession_Type proj_accession_Center  \
# Run
# SRR2401865              2015-09-15                 RUN            SUB1095135
# SRR2401866              2015-09-15                 RUN            SUB1095135
# SRR2401867              2015-09-15                 RUN            SUB1095135
# SRR2401868              2015-09-15                 RUN            SUB1095135
# SRR2401869              2015-09-15                 RUN            SUB1095135
# SRR2401870              2015-09-15                 RUN            SUB1095135
# SRR2401871              2015-09-15                 RUN            SUB1095135
# SRR2401872              2015-09-15                 RUN            SUB1095135
# SRR2407111              2015-09-15                 RUN            SUB1095135
# DRR000001               2009-06-20                 RUN                  KEIO
# DRR000002               2009-08-04                 RUN                  KEIO
# DRR000003               2009-08-06                 RUN                UT-MGS
# DRR000004               2009-08-06                 RUN                UT-MGS
# DRR000005               2009-08-06                 RUN                UT-MGS
# DRR000006               2009-08-06                 RUN                UT-MGS
# DRR000007               2009-08-06                 RUN                UT-MGS
# DRR000363               2010-04-19                 RUN                UT-MGS
# DRR000364               2010-04-19                 RUN                UT-MGS
# DRR000365               2010-04-19                 RUN                UT-MGS
# DRR000366               2010-04-19                 RUN                UT-MGS
# DRR000008               2009-08-06                 RUN                UT-MGS
# DRR000009               2009-08-06                 RUN                UT-MGS
# DRR000010               2009-08-06                 RUN                UT-MGS
# DRR000011               2009-08-06                 RUN                UT-MGS
# DRR000012               2009-08-06                 RUN                UT-MGS
# DRR000013               2009-08-06                 RUN                UT-MGS
# DRR000014               2009-08-06                 RUN                UT-MGS
# DRR000015               2009-08-06                 RUN                UT-MGS
# DRR000016               2009-08-06                 RUN                UT-MGS
# DRR000017               2009-08-06                 RUN                UT-MGS
#
#            proj_accession_Visibility proj_accession_Loaded  \
# Run
# SRR2401865                    public                     1
# SRR2401866                    public                     1
# SRR2401867                    public                     1
# SRR2401868                    public                     1
# SRR2401869                    public                     1
# SRR2401870                    public                     1
# SRR2401871                    public                     1
# SRR2401872                    public                     1
# SRR2407111                    public                     1
# DRR000001                     public                     1
# DRR000002                     public                     1
# DRR000003                     public                     1
# DRR000004                     public                     1
# DRR000005                     public                     1
# DRR000006                     public                     1
# DRR000007                     public                     1
# DRR000363                     public                     1
# DRR000364                     public                     1
# DRR000365                     public                     1
# DRR000366                     public                     1
# DRR000008                     public                     1
# DRR000009                     public                     1
# DRR000010                     public                     1
# DRR000011                     public                     1
# DRR000012                     public                     1
# DRR000013                     public                     1
# DRR000014                     public                     1
# DRR000015                     public                     1
# DRR000016                     public                     1
# DRR000017                     public                     1
#
#            proj_accession_ReplacedBy  \
# Run
# SRR2401865                         -
# SRR2401866                         -
# SRR2401867                         -
# SRR2401868                         -
# SRR2401869                         -
# SRR2401870                         -
# SRR2401871                         -
# SRR2401872                         -
# SRR2407111                         -
# DRR000001                          -
# DRR000002                          -
# DRR000003                          -
# DRR000004                          -
# DRR000005                          -
# DRR000006                          -
# DRR000007                          -
# DRR000363                          -
# DRR000364                          -
# DRR000365                          -
# DRR000366                          -
# DRR000008                          -
# DRR000009                          -
# DRR000010                          -
# DRR000011                          -
# DRR000012                          -
# DRR000013                          -
# DRR000014                          -
# DRR000015                          -
# DRR000016                          -
# DRR000017                          -
#
#                                     new_ScientificName Run_db Run_digits
# Run
# SRR2401865                             soil_metagenome    SRR    2401865
# SRR2401866                             soil_metagenome    SRR    2401866
# SRR2401867                             soil_metagenome    SRR    2401867
# SRR2401868                             soil_metagenome    SRR    2401868
# SRR2401869                             soil_metagenome    SRR    2401869
# SRR2401870                             soil_metagenome    SRR    2401870
# SRR2401871                             soil_metagenome    SRR    2401871
# SRR2401872                             soil_metagenome    SRR    2401872
# SRR2407111                             soil_metagenome    SRR    2407111
# DRR000001       Bacillus_subtilis_subsp._natto_BEST195    DRR          1
# DRR000002   Bacillus_subtilis_subsp._subtilis_str._168    DRR          2
# DRR000003                                 Homo_sapiens    DRR          3
# DRR000004                                 Homo_sapiens    DRR          4
# DRR000005                                 Homo_sapiens    DRR          5
# DRR000006                                 Homo_sapiens    DRR          6
# DRR000007                                 Homo_sapiens    DRR          7
# DRR000363                                 Homo_sapiens    DRR        363
# DRR000364                                 Homo_sapiens    DRR        364
# DRR000365                                 Homo_sapiens    DRR        365
# DRR000366                                 Homo_sapiens    DRR        366
# DRR000008                                 Homo_sapiens    DRR          8
# DRR000009                                 Homo_sapiens    DRR          9
# DRR000010                                 Homo_sapiens    DRR         10
# DRR000011                                 Homo_sapiens    DRR         11
# DRR000012                                 Homo_sapiens    DRR         12
# DRR000013                                 Homo_sapiens    DRR         13
# DRR000014                                 Homo_sapiens    DRR         14
# DRR000015                                 Homo_sapiens    DRR         15
# DRR000016                                 Homo_sapiens    DRR         16
# DRR000017                                 Homo_sapiens    DRR         17
#
# [30 rows x 23 columns]

# %% [markdown]
# #  biospcieman metadata (SRA SRS)

# %%
allSRS_pickle_dir='/cellar/users/btsui/Data/SRA/DUMP/allSRS.pickle.gz'
allSRS=pd.read_pickle(allSRS_pickle_dir)

# %%
len(allSRS)
# Out:
# 46851228

# %%
allSRS.head(n=30)
# Out:
# ERS018283   SUBMITTER_ID                               0073_93-sc-2011-01-25-1067919
#             Strain                                                           0073/93
#             Sample Description
# ERS166165   TITLE                                              Staphylococcus aureus
#             SCIENTIFIC_NAME                                    Staphylococcus aureus
#             SUBMITTER_ID                 09_052_0024-sc-2012-08-23T16:02:15Z-1473554
#             Strain                                                       09-052-0024
#             Sample Description
#             ArrayExpress-StrainOrLine                                    09-052-0024
#             ArrayExpress-Sex                                          not applicable
#             ArrayExpress-Species                               Staphylococcus aureus
# SRS602849   SCIENTIFIC_NAME                                      Salmonella enterica
#             SUBMITTER_ID                                                     FSW0167
#             strain                                                           FSW0167
#             collected_by                                                         FDA
#             collection_date                                               2013-12-05
#             isolation_source                  frozen tilapia whole round farm raised
#             geo_loc_name                                                      Taiwan
#             lat_lon                                                          missing
#             BioSampleModel                                                  Pathogen
#             BioSampleModel                                  environmental/food/other
# ERS1791024  TITLE                                   5478_87_1_PBMC_T1_EBNA3C_UM87_1B
#             SCIENTIFIC_NAME                                 Human gammaherpesvirus 4
#             SUBMITTER_ID                        a91c9580-7d08-11e3-8f5e-3c4a9275d6c6
#             SUBJECT_ID                                                425STDY5706061
#             PHENOTYPE                                                            N/A
#             ArrayExpress-PHENOTYPE                                               N/A
#             ArrayExpress-SPECIES                                 Human herpesvirus 4
# ERS069382   TITLE                                           Streptococcus pneumoniae
#             SCIENTIFIC_NAME                                 Streptococcus pneumoniae
# dtype: object

# %% [markdown]
# # experiment metadata

# %%
allSRX_pickle_dir='/cellar/users/btsui/Data/SRA/DUMP/allSRX.pickle.gz'
allSRX=pd.read_pickle(allSRX_pickle_dir)

# %%
len(allSRX)
# Out:
# 24746456

# %%
allSRX.head(n=30)
# Out:
# ERX1269638  TITLE                Illumina HiSeq 1500 paired end sequencing
#             LIBRARY_STRATEGY                                           EST
#             LIBRARY_SOURCE                                         GENOMIC
#             LIBRARY_SELECTION                                       RANDOM
#             LIBRARY_LAYOUT                                          PAIRED
# ERX1269639  TITLE                Illumina HiSeq 1500 paired end sequencing
#             LIBRARY_STRATEGY                                           EST
#             LIBRARY_SOURCE                                         GENOMIC
#             LIBRARY_SELECTION                                       RANDOM
#             LIBRARY_LAYOUT                                          PAIRED
# ERX1269640  TITLE                Illumina HiSeq 1500 paired end sequencing
#             LIBRARY_STRATEGY                                           EST
#             LIBRARY_SOURCE                                         GENOMIC
#             LIBRARY_SELECTION                                       RANDOM
#             LIBRARY_LAYOUT                                          PAIRED
# ERX1269641  TITLE                Illumina HiSeq 1500 paired end sequencing
#             LIBRARY_STRATEGY                                           EST
#             LIBRARY_SOURCE                                         GENOMIC
#             LIBRARY_SELECTION                                       RANDOM
#             LIBRARY_LAYOUT                                          PAIRED
# ERX1269642  TITLE                Illumina HiSeq 1500 paired end sequencing
#             LIBRARY_STRATEGY                                           EST
#             LIBRARY_SOURCE                                         GENOMIC
#             LIBRARY_SELECTION                                       RANDOM
#             LIBRARY_LAYOUT                                          PAIRED
# ERX1269643  TITLE                Illumina HiSeq 1500 paired end sequencing
#             LIBRARY_STRATEGY                                           EST
#             LIBRARY_SOURCE                                         GENOMIC
#             LIBRARY_SELECTION                                       RANDOM
#             LIBRARY_LAYOUT                                          PAIRED
# dtype: object
