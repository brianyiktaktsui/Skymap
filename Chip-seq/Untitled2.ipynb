# %%
import pandas as pd

# %%
#!wget ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM1436nnn/GSM1436261/suppl/GSM1436261_ENCFF002ENH.bed.gz
# Out:
# --2017-11-24 05:46:35--  ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM1436nnn/GSM1436261/suppl/GSM1436261_ENCFF002ENH.bed.gz
#            => ‘GSM1436261_ENCFF002ENH.bed.gz’
# Resolving ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)... 130.14.250.10, 2607:f220:41e:250::13
# Connecting to ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)|130.14.250.10|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /geo/samples/GSM1436nnn/GSM1436261/suppl ... done.
# ==> SIZE GSM1436261_ENCFF002ENH.bed.gz ... 118874
# ==> PASV ... done.    ==> RETR GSM1436261_ENCFF002ENH.bed.gz ... done.
# Length: 118874 (116K) (unauthoritative)
#
# GSM1436261_ENCFF002 100%[===================>] 116.09K   558KB/s    in 0.2s
#
# 2017-11-24 05:46:37 (558 KB/s) - ‘GSM1436261_ENCFF002ENH.bed.gz’ saved [118874]

# %%
GSM1436261_df=pd.read_csv('GSM1436261_ENCFF002ENH.bed.gz',sep='\t',header=None)
# Out:
#           0          1          2
# 0      chrX    2746600    2747799
# 1      chrX    3629400    3632599
# 2      chrX    3732200    3734999
# 3      chrX    7064600    7066799
# 4      chrX    7893800    7896399
# 5      chrX    9309800    9311599
# 6      chrX    9430200    9436199
# 7      chrX   11127600   11131199
# 8      chrX   11283200   11286199
# 9      chrX   11368600   11372599
# 10     chrX   11396000   11398399
# 11     chrX   11440800   11446599
# 12     chrX   11455400   11457999
# 13     chrX   11775400   11779399
# 14     chrX   12808800   12811999
# 15     chrX   12974400   12976799
# 16     chrX   12982400   12984999
# 17     chrX   12992000   12997199
# 18     chrX   13309400   13312399
# 19     chrX   13670400   13673599
# 20     chrX   13706600   13709399
# 21     chrX   13749600   13754999
# 22     chrX   14045400   14048999
# 23     chrX   14890000   14893799
# 24     chrX   15352000   15355199
# 25     chrX   15510600   15513199
# ...
